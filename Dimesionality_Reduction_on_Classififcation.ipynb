# %% [markdown]
# ## Dimensionality Reduction - Classification

# %% [markdown]
# Blog Link :https://medium.com/@muzammila784/dimensionality-reduction-does-approach-matter-58d5cd0915c3

# %% [markdown]
# #### BackGround

# %% [markdown]
# In machine learning problems, there are many factors that contribute to the final prediction. Some of these features are highly correlated with the target variable, and some are negatively correlated. Having too many features increases the computational time and sometimes reduces the accuracy of the model, as some models are designed such that they are not able to perform well on high-dimensional data. This is where dimensionality reduction is used. It is a process or technique of reducing the number of features without compromising the accuracy of the model and reducing the computational time, which makes it better for models to learn patterns more precisely as compared to high-dimensional datasets.
#
# The number of features is represented by dimensions. To make the problem simpler and make learning easier, we use dimensionality reduction techniques that map high-dimensional features into low-dimensional space. It is an old technique for reducing the dimensions of large datasets, but it still outperforms many traditional algorithms and newer techniques.

# %% [markdown]
# #### Dimensionality Reduction Techniques

# %% [markdown]
# In this project, we are using 15 different datasets and evaluating the performance of different machine learning models after doing dimensionality reduction with different approaches. The approaches we are using in this project are:
#
#
# 1- Principal Component Analysis (PCA) :-
#
# Principal component analysis (PCA) is the process of calculating and analyzing the key characteristics of data and using them to change the data’s underlying structure, frequently using only the first few key characteristics, and ignoring the rest. The primary objective of PCA is to learn the pattern of variances, and its major objective is to prevent the pattern of variances from being altered during dimensionality reduction.
#
#
# 2- Linear Discriminant Analysis (LDA) :-
#
# In this technique, we compute a scatter matrix, which tells us about the amount of dispersion within and between classes. As a result, we compute two matrices for the inter-class and intra-class matrices. LDA find linear combinations in the dataset so that classes remain separated.
#
#
# 3- T-SNE : -
#
# TSN-E works on non-linear datasets and calculates similarity in between instances, high dimensional space and low dimensional space and then optimize these two similarities using a cost function.
#
#
# 4- Singular Vector Decomposition : -
#
# The sole distinction between this method and PCA is that, in this case, the data matrix is used as the matrix to be factorized rather than the covariance matrix as it is in PCA. While PCA performs better with dense data, SVD performs better with sparse data.
#
#
# 5- Isomap Embedding : -
#
# The isomap technique uses a non-linear approach to minimize dimensions while preserving local structures. It is distinct from a few other methods in the same class because it employs a non-linear method of dimensionality reduction as opposed to the linear mappings employed by algorithms like PCA.

# %% [markdown]
# #### Datasets

# %% [markdown]
# We are using eight classification and seven regression datasets to check the performance before and after reducing features.
#
# Classification
#
# 1- Chronic Kidney Disease Dataset
#
# 2: Blood Pressure Disease Dataset
#
# 3- Cardiovascular Disease Dataset
#
# 4- Heart Disease Prediction Dataset
#
# 5- Credit Card Fraud Dataset
#
# 6- Customer churn Dataset
#
# 7- Brest Cancer Wisconsin Dataset
#
# 8-Accident Severity Prediction Dataset

# %% [markdown]
# #### Pre - Processing

# %% [markdown]
# Our pre-processing pipeline consists of the following steps:
#
# 1- The first step is to check the data types of columns and convert categorical columns into numerical columns using mapping or encoding techniques.
#
# 2- Dropping columns, which are redundant and unnecessary,
#
# 3- The second step is to check for null values and fill all the null values with either the mean, the previous value, or dropping the value.
#
# 4- The third step is scaling the data, which is mandatory before dimensionality reduction. We are doing scaling using the standard scaling method.
#
# 5- Splitting our dataset into train and test set with 70–30% ratio.

# %% [markdown]
# #### Machine Learning and Dimensionality Reduction Pipeline

# %% [markdown]
# So, our second pipeline will implement machine learning models and dimensionality reduction techniques on a dataset. This pipeline contains the following steps:
#
# 1- Applying machine learning models to a full-featured dataset using lazy prediction and getting results
#
# 2- PCA and Lazy Predict are applied to the reduced-dimensioned data, and the results are checked.
#
# 3- Implementing LDA and applying lazy prediction to the reduced data of LDA
#
# 4- Similarly, we will repeat the process of TSNE, SVD, and Isomap embedding.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd   
import matplotlib.pyplot as plt
import plotly.express as px
import time
import numpy as np
import warnings

from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import RFE,SelectFromModel


from sklearn.model_selection import train_test_split, RepeatedKFold, GridSearchCV, cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import KFold, cross_val_score

from sklearn.pipeline import Pipeline
from matplotlib import pyplot
# the permutation based importance
import seaborn as sns
from sklearn.inspection import permutation_importance

from numpy import mean
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset 1 : Chronic Kidney Disease

# %% [markdown]
# Data info : This dataset of chronic kidney disease is taken from UCI Machine learning repository. Its a binary classsification dataset having 26 features and 400 instances.
#
# link for the is https://archive.ics.uci.edu/ml/datasets/chronic_kidney_disease

# %% [markdown]
# ### Loading Dataset

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:\DOWNLOADS\kidney_disease.csv")
data.shape
# Out:
# (400, 26)

# %% [markdown]
# ### Data Pre Processing

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
# Counting Number of Attrition.
dictribution = data["classification"].value_counts()
dictribution
# Out:
# ckd       248
# notckd    150
# ckd\t       2
# Name: classification, dtype: int64

# %%
# Replacing '/t' from classififcation column records.
data['classification'] = data['classification'].str.replace(r'\t', '')

# %%
# Counting Number of Attrition.
dictribution = data["classification"].value_counts()
dictribution
# Out:
# ckd       250
# notckd    150
# Name: classification, dtype: int64

# %%
# Cleaning columns and removing extra punctuations from numeric columns
data['pcv'] = data['pcv'].str.replace(r'?', '0')
data['wc'] = data['wc'].str.replace(r'?', '0')
data['rc'] = data['rc'].str.replace(r'?', '0')
data['dm'] = data['dm'].str.replace(r' ', '')

# %%
# now converting string columns into numeric after removing punctuations.
data['pcv'] = pd.to_numeric(data['pcv'])
data['wc'] = pd.to_numeric(data['wc'])
data['rc'] = pd.to_numeric(data['rc'])

# %%
# Checking Null values in all features.
data.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['age'].fillna(value= 51, inplace=True)

data['bp'].fillna(value= 76, inplace=True)

#Finding the mean of the Specific Gravity column having NaN
mean_value=data['sg'].mean()
#print(mean_value)
data['sg'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Albumin column having NaN
mean_value=data['al'].mean()
print(mean_value)
data['al'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Sugar column having NaN
mean_value=data['su'].mean()
print(mean_value)
data['su'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Blood Glucose Random column having NaN
mean_value=data['bgr'].mean()
print(mean_value)
data['bgr'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Blood urea column having NaN
mean_value=data['bu'].mean()
print(mean_value)
data['bu'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Serum Creatine column having NaN
mean_value=data['sc'].mean()
print(mean_value)
data['sc'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Sodium column having NaN
mean_value=data['sod'].mean()
print(mean_value)
data['sod'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Potassium column having NaN
mean_value=data['pot'].mean()
print(mean_value)
data['pot'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Hemoglobin column having NaN
mean_value=data['hemo'].mean()
print(mean_value)
data['hemo'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Packed Cell Volume column having NaN
mean_value=data['pcv'].mean()
print(mean_value)
data['pcv'].fillna(value= mean_value, inplace=True)

#Finding the mean of the White Blood Cells column having NaN
mean_value=data['wc'].mean()
print(mean_value)
data['wc'].fillna(value= mean_value, inplace=True)

#Finding the mean of the Red Blood cells column having NaN
mean_value=data['rc'].mean()
print(mean_value)
data['rc'].fillna(value= mean_value, inplace=True)
# Out:
# 1.0169491525423728
# 0.45014245014245013
# 148.0365168539326
# 57.425721784776904
# 3.072454308093995
# 137.52875399361022
# 4.62724358974359
# 12.526436781609195
# 38.766666666666666
# 8377.627118644068
# 4.689999999999999

# %%
# Replacing null values if categorical columns with mode
mode_value=data['pc'].mode()[0]
data['pc'].fillna(value= mode_value, inplace=True)

mode_value=data['pcc'].mode()[0]
data['pcc'].fillna(value= mode_value, inplace=True)

mode_value=data['ba'].mode()[0]
data['ba'].fillna(value= mode_value, inplace=True)

mode_value=data['htn'].mode()[0]
data['htn'].fillna(value= mode_value, inplace=True)

mode_value=data['cad'].mode()[0]
data['cad'].fillna(value= mode_value, inplace=True)

mode_value=data['appet'].mode()[0]
data['appet'].fillna(value= mode_value, inplace=True)

mode_value=data['pe'].mode()[0]
data['pe'].fillna(value= mode_value, inplace=True)

mode_value=data['ane'].mode()[0]
data['ane'].fillna(value= mode_value, inplace=True)

mode_value=data['dm'].mode()[0]
data['dm'].fillna(value= mode_value, inplace=True)

# %%
# Checking Null values in all features.
data.isnull().sum()
# Out:
# id                  0
# age                 0
# bp                  0
# sg                  0
# al                  0
# su                  0
# rbc               152
# pc                  0
# pcc                 0
# ba                  0
# bgr                 0
# bu                  0
# sc                  0
# sod                 0
# pot                 0
# hemo                0
# pcv                 0
# wc                  0
# rc                  0
# htn                 0
# dm                  0
# cad                 0
# appet               0
# pe                  0
# ane                 0
# classification      0
# dtype: int64

# %%
# Dropping unimpactful colums
data.drop('id',axis=1,inplace=True)
data.drop('rbc',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   pc              400 non-null    object
#  6   pcc             400 non-null    object
#  7   ba              400 non-null    object
#  8   bgr             400 non-null    float64
#  9   bu              400 non-null    float64
#  10  sc              400 non-null    float64
#  11  sod             400 non-null    float64
#  12  pot             400 non-null    float64
#  13  hemo            400 non-null    float64
#  14  pcv             400 non-null    float64
#  15  wc              400 non-null    float64
#  16  rc              400 non-null    float64
#  17  htn             400 non-null    object
#  18  dm              400 non-null    object
#  19  cad             400 non-null    object
#  20  appet           400 non-null    object
#  21  pe              400 non-null    object
#  22  ane             400 non-null    object
#  23  classification  400 non-null    object
# dtypes: float64(14), object(10)
# memory usage: 75.1+ KB

# %%
data['pc'] = data['pc'].map({'normal': 0, 'abnormal': 1})
data['pc'] = pd.to_numeric(data['pc'])

data['pcc'] = data['pcc'].map({'notpresent': 0, 'present': 1})
data['pcc'] = pd.to_numeric(data['pcc'])

data['ba'] = data['pcc'].map({'notpresent': 0, 'present': 1})
data['ba'] = pd.to_numeric(data['ba'])

data['htn'] = data['htn'].map({'no': 0, 'yes': 1})
data['htn'] = pd.to_numeric(data['htn'])

data['dm'] = data['dm'].map({'no': 0, 'yes': 1})
data['dm'] = pd.to_numeric(data['dm'])

data['cad'] = data['cad'].map({'no': 0, 'yes': 1})
data['cad'] = pd.to_numeric(data['cad'])

data['appet'] = data['appet'].map({'good': 1, 'poor': 0})
data['appet'] = pd.to_numeric(data['appet'])

data['pe'] = data['pe'].map({'no': 0, 'yes': 1})
data['pe'] = pd.to_numeric(data['pe'])

data['ane'] = data['ane'].map({'no': 0, 'yes': 1})
data['ane'] = pd.to_numeric(data['ane'])

data['classification'] = data['classification'].map({'notckd': 0, 'ckd': 1})
data['classification'] = pd.to_numeric(data['classification'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   pc              400 non-null    int64
#  6   pcc             400 non-null    int64
#  7   ba              0 non-null      float64
#  8   bgr             400 non-null    float64
#  9   bu              400 non-null    float64
#  10  sc              400 non-null    float64
#  11  sod             400 non-null    float64
#  12  pot             400 non-null    float64
#  13  hemo            400 non-null    float64
#  14  pcv             400 non-null    float64
#  15  wc              400 non-null    float64
#  16  rc              400 non-null    float64
#  17  htn             400 non-null    int64
#  18  dm              400 non-null    int64
#  19  cad             400 non-null    int64
#  20  appet           400 non-null    int64
#  21  pe              400 non-null    int64
#  22  ane             400 non-null    int64
#  23  classification  400 non-null    int64
# dtypes: float64(15), int64(9)
# memory usage: 75.1 KB

# %%
data.drop('ba',axis=1,inplace=True)

# %% [markdown]
# ### Splitting Dataset into X and Y Variables

# %%
X = data.loc[:, data.columns != 'classification']
y = data[['classification']]

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
X_scaled.head()
# Out:
#         age        bp        sg        al        su        pc       pcc  \
# 0 -0.204820  0.263379  0.483355 -0.013338 -0.437797 -0.484322 -0.342518
# 1 -2.623145 -1.965500  0.483355  2.347516 -0.437797 -0.484322 -0.342518
# 2  0.620949  0.263379 -1.381391  0.773613  2.479925 -0.484322 -0.342518
# 3 -0.204820 -0.479581 -2.313764  2.347516 -0.437797  2.064742  2.919556
# 4 -0.027870  0.263379 -1.381391  0.773613 -0.437797 -0.484322 -0.342518
#
#         bgr        bu        sc  ...      hemo       pcv        wc  \
# 0 -0.361987 -0.435268 -0.333743  ...  1.059271  0.625313 -0.226099
# 1  0.000000 -0.800941 -0.405039  ... -0.452097 -0.091606 -0.930667
# 2  3.681441 -0.089909 -0.226800  ... -1.078762 -0.928012 -0.343527
# 3 -0.415543 -0.028964  0.129677  ... -0.488960 -0.808525 -0.656668
# 4 -0.562820 -0.638420 -0.298096  ... -0.341509 -0.450066 -0.421812
#
#              rc       htn        dm       cad     appet        pe       ane
# 0  5.851805e-01  1.311903  1.385535 -0.304789  0.507801 -0.484322 -0.420084
# 1 -1.019107e-15 -0.762252 -0.721743 -0.304789  0.507801 -0.484322 -0.420084
# 2 -1.019107e-15 -0.762252  1.385535 -0.304789 -1.969276 -0.484322  2.380476
# 3 -9.064561e-01  1.311903 -0.721743 -0.304789 -1.969276  2.064742  2.380476
# 4 -1.032671e-01 -0.762252 -0.721743 -0.304789  0.507801 -0.484322 -0.420084
#
# [5 rows x 22 columns]

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 22)
# (280, 1)
# (120, 22)
# (120, 1)

# %% [markdown]
# Implementing Lazy predict on full dataset before dimensionality reduction

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 13.13it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# XGBClassifier                      0.99               0.99     0.99      0.99
# NuSVC                              0.99               0.99     0.99      0.99
# AdaBoostClassifier                 0.99               0.99     0.99      0.99
# CalibratedClassifierCV             0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# PassiveAggressiveClassifier        0.98               0.99     0.99      0.98
# Perceptron                         0.98               0.99     0.99      0.98
# BernoulliNB                        0.98               0.99     0.99      0.98
# DecisionTreeClassifier             0.98               0.99     0.99      0.98
# LinearSVC                          0.98               0.99     0.99      0.98
# BaggingClassifier                  0.97               0.98     0.98      0.98
# RidgeClassifierCV                  0.97               0.97     0.97      0.97
# KNeighborsClassifier               0.96               0.97     0.97      0.96
# RidgeClassifier                    0.95               0.96     0.96      0.95
# LinearDiscriminantAnalysis         0.95               0.96     0.96      0.95
# GaussianNB                         0.95               0.96     0.96      0.95
# ExtraTreeClassifier                0.96               0.96     0.96      0.96
# LabelSpreading                     0.94               0.96     0.96      0.94
# LabelPropagation                   0.94               0.96     0.96      0.94
# NearestCentroid                    0.88               0.91     0.91      0.89
# DummyClassifier                    0.65               0.50     0.50      0.51
# QuadraticDiscriminantAnalysis      0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# LGBMClassifier                       0.12
# ExtraTreesClassifier                 0.17
# SVC                                  0.02
# RandomForestClassifier               0.23
# LogisticRegression                   0.04
# XGBClassifier                        0.10
# NuSVC                                0.04
# AdaBoostClassifier                   0.50
# CalibratedClassifierCV               0.10
# SGDClassifier                        0.02
# PassiveAggressiveClassifier          0.03
# Perceptron                           0.02
# BernoulliNB                          0.06
# DecisionTreeClassifier               0.03
# LinearSVC                            0.02
# BaggingClassifier                    0.14
# RidgeClassifierCV                    0.02
# KNeighborsClassifier                 0.26
# RidgeClassifier                      0.02
# LinearDiscriminantAnalysis           0.03
# GaussianNB                           0.02
# ExtraTreeClassifier                  0.02
# LabelSpreading                       0.05
# LabelPropagation                     0.04
# NearestCentroid                      0.03
# DummyClassifier                      0.03
# QuadraticDiscriminantAnalysis        0.03

# %% [markdown]
# ### Dimensionality Reduction Algorithms

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=8)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5', 'principal component 6','principal component 7', 'principal component 8'])

# %%
PCA_Df.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0              -0.901751              -0.669985               0.734580
# 1              -1.228522               0.984284              -1.212028
# 2               2.957758              -2.463542               0.657733
# 3               4.363778               1.928367              -3.008661
# 4              -0.457323               0.404681              -0.421620
#
#    principal component 4  principal component 5  principal component 6  \
# 0              -0.562227              -0.314508               0.109762
# 1               0.793283               1.033842              -0.189207
# 2               0.435719              -1.431037              -1.569641
# 3              -0.309425               2.279219              -0.562898
# 4              -0.015137              -0.039227              -0.869486
#
#    principal component 7  principal component 8
# 0               0.140686              -0.145920
# 1              -1.531347              -2.165175
# 2              -1.407006              -1.329318
# 3               0.067209              -1.094770
# 4              -0.128037               0.006296

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 8)
# (280, 1)
# (120, 8)
# (120, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 11.83it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# CalibratedClassifierCV             0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# PassiveAggressiveClassifier        0.99               0.99     0.99      0.99
# AdaBoostClassifier                 0.99               0.99     0.99      0.99
# LabelSpreading                     0.98               0.99     0.99      0.98
# LabelPropagation                   0.98               0.99     0.99      0.98
# Perceptron                         0.98               0.99     0.99      0.98
# GaussianNB                         0.98               0.99     0.99      0.98
# RidgeClassifier                    0.98               0.99     0.99      0.98
# RidgeClassifierCV                  0.98               0.99     0.99      0.98
# LGBMClassifier                     0.98               0.98     0.98      0.98
# LinearDiscriminantAnalysis         0.97               0.98     0.98      0.98
# KNeighborsClassifier               0.97               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.97               0.98     0.98      0.98
# NuSVC                              0.97               0.97     0.97      0.97
# ExtraTreeClassifier                0.94               0.94     0.94      0.94
# NearestCentroid                    0.93               0.94     0.94      0.93
# BernoulliNB                        0.88               0.89     0.89      0.88
# DummyClassifier                    0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# LinearSVC                            0.02
# BaggingClassifier                    0.14
# XGBClassifier                        0.10
# DecisionTreeClassifier               0.11
# SVC                                  0.03
# ExtraTreesClassifier                 0.40
# RandomForestClassifier               0.39
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.15
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.04
# AdaBoostClassifier                   0.42
# LabelSpreading                       0.02
# LabelPropagation                     0.03
# Perceptron                           0.03
# GaussianNB                           0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# LGBMClassifier                       0.13
# LinearDiscriminantAnalysis           0.02
# KNeighborsClassifier                 0.02
# QuadraticDiscriminantAnalysis        0.03
# NuSVC                                0.03
# ExtraTreeClassifier                  0.07
# NearestCentroid                      0.02
# BernoulliNB                          0.05
# DummyClassifier                      0.02

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 1)
# (280, 1)
# (120, 1)
# (120, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 20.38it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# KNeighborsClassifier               1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SGDClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# Perceptron                         1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# LinearDiscriminantAnalysis         0.99               0.99     0.99      0.99
# RidgeClassifierCV                  0.99               0.99     0.99      0.99
# RidgeClassifier                    0.99               0.99     0.99      0.99
# GaussianNB                         0.99               0.99     0.99      0.99
# SVC                                0.99               0.99     0.99      0.99
# CalibratedClassifierCV             0.99               0.99     0.99      0.99
# QuadraticDiscriminantAnalysis      0.99               0.99     0.99      0.99
# PassiveAggressiveClassifier        0.99               0.99     0.99      0.99
# NuSVC                              0.99               0.99     0.99      0.99
# LogisticRegression                 0.99               0.99     0.99      0.99
# ExtraTreeClassifier                0.99               0.99     0.99      0.99
# LabelSpreading                     0.99               0.99     0.99      0.99
# LabelPropagation                   0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# NearestCentroid                    0.97               0.97     0.97      0.97
# BernoulliNB                        0.88               0.91     0.91      0.89
# DummyClassifier                    0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.24
# KNeighborsClassifier                 0.04
# XGBClassifier                        0.08
# SGDClassifier                        0.02
# RandomForestClassifier               0.29
# Perceptron                           0.02
# BaggingClassifier                    0.04
# LGBMClassifier                       0.07
# ExtraTreesClassifier                 0.17
# DecisionTreeClassifier               0.02
# LinearDiscriminantAnalysis           0.02
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.02
# GaussianNB                           0.02
# SVC                                  0.02
# CalibratedClassifierCV               0.06
# QuadraticDiscriminantAnalysis        0.02
# PassiveAggressiveClassifier          0.02
# NuSVC                                0.03
# LogisticRegression                   0.02
# ExtraTreeClassifier                  0.03
# LabelSpreading                       0.03
# LabelPropagation                     0.02
# LinearSVC                            0.03
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# DummyClassifier                      0.01

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 2)
# (280, 1)
# (120, 2)
# (120, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 22.85it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# KNeighborsClassifier               0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# RandomForestClassifier             0.99               0.99     0.99      0.99
# BaggingClassifier                  0.99               0.99     0.99      0.99
# LabelSpreading                     0.99               0.99     0.99      0.99
# LabelPropagation                   0.99               0.99     0.99      0.99
# AdaBoostClassifier                 0.99               0.99     0.99      0.99
# ExtraTreeClassifier                0.99               0.99     0.99      0.99
# LinearSVC                          0.98               0.99     0.99      0.98
# SVC                                0.98               0.99     0.99      0.98
# QuadraticDiscriminantAnalysis      0.98               0.99     0.99      0.98
# DecisionTreeClassifier             0.98               0.98     0.98      0.98
# CalibratedClassifierCV             0.97               0.98     0.98      0.98
# LogisticRegression                 0.97               0.98     0.98      0.98
# NuSVC                              0.97               0.98     0.98      0.98
# GaussianNB                         0.97               0.97     0.97      0.97
# Perceptron                         0.97               0.97     0.97      0.97
# PassiveAggressiveClassifier        0.96               0.97     0.97      0.96
# RidgeClassifier                    0.95               0.96     0.96      0.95
# RidgeClassifierCV                  0.95               0.96     0.96      0.95
# LinearDiscriminantAnalysis         0.95               0.96     0.96      0.95
# BernoulliNB                        0.95               0.96     0.96      0.95
# NearestCentroid                    0.94               0.96     0.96      0.94
# DummyClassifier                    0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# LGBMClassifier                       0.10
# XGBClassifier                        0.09
# ExtraTreesClassifier                 0.18
# KNeighborsClassifier                 0.02
# SGDClassifier                        0.02
# RandomForestClassifier               0.21
# BaggingClassifier                    0.05
# LabelSpreading                       0.03
# LabelPropagation                     0.02
# AdaBoostClassifier                   0.19
# ExtraTreeClassifier                  0.02
# LinearSVC                            0.02
# SVC                                  0.02
# QuadraticDiscriminantAnalysis        0.02
# DecisionTreeClassifier               0.02
# CalibratedClassifierCV               0.06
# LogisticRegression                   0.02
# NuSVC                                0.02
# GaussianNB                           0.02
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.02
# LinearDiscriminantAnalysis           0.02
# BernoulliNB                          0.01
# NearestCentroid                      0.02
# DummyClassifier                      0.02

# %% [markdown]
# ### Singular Vector Decomposition SVD

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=8)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 8)
# (280, 1)
# (120, 8)
# (120, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 17.90it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# SVC                                1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# LinearSVC                          1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        0.99               0.99     0.99      0.99
# CalibratedClassifierCV             0.99               0.99     0.99      0.99
# Perceptron                         0.98               0.99     0.99      0.98
# RidgeClassifierCV                  0.98               0.99     0.99      0.98
# RidgeClassifier                    0.98               0.99     0.99      0.98
# GaussianNB                         0.98               0.99     0.99      0.98
# LabelSpreading                     0.98               0.99     0.99      0.98
# LabelPropagation                   0.98               0.99     0.99      0.98
# LGBMClassifier                     0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.97               0.98     0.98      0.98
# LinearDiscriminantAnalysis         0.97               0.98     0.98      0.98
# SGDClassifier                      0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.97               0.98     0.98      0.98
# NuSVC                              0.97               0.97     0.97      0.97
# ExtraTreeClassifier                0.94               0.94     0.94      0.94
# NearestCentroid                    0.93               0.94     0.94      0.93
# BernoulliNB                        0.88               0.89     0.89      0.88
# DummyClassifier                    0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.19
# ExtraTreesClassifier                 0.25
# XGBClassifier                        0.08
# SVC                                  0.02
# RandomForestClassifier               0.29
# LogisticRegression                   0.02
# BaggingClassifier                    0.05
# LinearSVC                            0.02
# DecisionTreeClassifier               0.02
# PassiveAggressiveClassifier          0.03
# CalibratedClassifierCV               0.06
# Perceptron                           0.03
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.03
# GaussianNB                           0.02
# LabelSpreading                       0.02
# LabelPropagation                     0.04
# LGBMClassifier                       0.08
# KNeighborsClassifier                 0.10
# LinearDiscriminantAnalysis           0.02
# SGDClassifier                        0.02
# QuadraticDiscriminantAnalysis        0.03
# NuSVC                                0.05
# ExtraTreeClassifier                  0.03
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# DummyClassifier                      0.03

# %% [markdown]
# ### ISOMAP Embedding

# %%
from sklearn.manifold import Isomap
model = Isomap(n_components=2, n_neighbors=3)
# fit and transform the data
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (280, 2)
# (280, 1)
# (120, 2)
# (120, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 11.17it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.98               0.99     0.99      0.98
# LogisticRegression                 0.98               0.99     0.99      0.98
# GaussianNB                         0.97               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.97               0.98     0.98      0.98
# CalibratedClassifierCV             0.97               0.97     0.97      0.97
# SGDClassifier                      0.97               0.97     0.97      0.97
# PassiveAggressiveClassifier        0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# DecisionTreeClassifier             0.97               0.97     0.97      0.97
# ExtraTreesClassifier               0.97               0.97     0.97      0.97
# RandomForestClassifier             0.97               0.97     0.97      0.97
# SVC                                0.96               0.97     0.97      0.96
# LabelPropagation                   0.96               0.97     0.97      0.96
# LabelSpreading                     0.96               0.97     0.97      0.96
# AdaBoostClassifier                 0.97               0.96     0.96      0.97
# KNeighborsClassifier               0.95               0.96     0.96      0.95
# BaggingClassifier                  0.95               0.96     0.96      0.95
# Perceptron                         0.93               0.95     0.95      0.93
# LGBMClassifier                     0.95               0.95     0.95      0.95
# NuSVC                              0.93               0.94     0.94      0.93
# LinearDiscriminantAnalysis         0.93               0.94     0.94      0.93
# RidgeClassifier                    0.93               0.94     0.94      0.93
# RidgeClassifierCV                  0.93               0.94     0.94      0.93
# NearestCentroid                    0.91               0.93     0.93      0.91
# ExtraTreeClassifier                0.93               0.92     0.92      0.93
# BernoulliNB                        0.92               0.92     0.92      0.92
# DummyClassifier                    0.65               0.50     0.50      0.51
#
#                                Time Taken
# Model
# LinearSVC                            0.03
# LogisticRegression                   0.04
# GaussianNB                           0.04
# QuadraticDiscriminantAnalysis        0.03
# CalibratedClassifierCV               0.12
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.03
# XGBClassifier                        0.16
# DecisionTreeClassifier               0.06
# ExtraTreesClassifier                 0.42
# RandomForestClassifier               0.52
# SVC                                  0.03
# LabelPropagation                     0.04
# LabelSpreading                       0.06
# AdaBoostClassifier                   0.33
# KNeighborsClassifier                 0.05
# BaggingClassifier                    0.11
# Perceptron                           0.04
# LGBMClassifier                       0.12
# NuSVC                                0.04
# LinearDiscriminantAnalysis           0.04
# RidgeClassifier                      0.06
# RidgeClassifierCV                    0.04
# NearestCentroid                      0.03
# ExtraTreeClassifier                  0.03
# BernoulliNB                          0.03
# DummyClassifier                      0.03

# %% [markdown]
# ## Dataset 2: Blood Pressure Prediction Dataset

# %% [markdown]
# Dataset Info : Dataset we are using in this case study is named as “Blood pressure data for disease prediction” and contains medical information of patients. Dataset contains 2000 patients records and 15 features. We are using “Blood pressure abnormality” as our target variable. It is a Binary class classification problem, where value of class is 0 and 1 (0 means disease not detected and 1 means disease detected). Dataset is balanced and consist of 14 attributes other than target attribute.

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:\DOWNLOADS\Datasets\data.csv")
data.shape
# Out:
# (2000, 15)

# %%
data.head()
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1       1.00        0
# 1                          0.23   54   33    1        NaN        0
# 2                          0.91   70   49    0        NaN        0
# 3                          0.43   71   50    0        NaN        0
# 4                          0.83   52   19    0        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# 1              26106                     25333                       205.00
# 2               9995                     29465                        67.00
# 3              10635                      7439                       242.00
# 4              15619                     49644                       397.00
#
#    Level_of_Stress  Chronic_kidney_disease  Adrenal_and_thyroid_disorders
# 0                2                       1                              1
# 1                3                       0                              0
# 2                2                       1                              0
# 3                1                       1                              0
# 4                2                       0                              0

# %%
# Checking Null values in all features.
data.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
#Solving for Null Values and adding 0 in null spaces.
data['Pregnancy'] = data['Pregnancy'].fillna(0)
data['alcohol_consumption_per_day'] = data['alcohol_consumption_per_day'].fillna(0)

# %%
# Checking Null Values again.
data.isnull().sum()
# Out:
# Patient_Number                    0
# Blood_Pressure_Abnormality        0
# Level_of_Hemoglobin               0
# Genetic_Pedigree_Coefficient     92
# Age                               0
# BMI                               0
# Sex                               0
# Pregnancy                         0
# Smoking                           0
# Physical_activity                 0
# salt_content_in_the_diet          0
# alcohol_consumption_per_day       0
# Level_of_Stress                   0
# Chronic_kidney_disease            0
# Adrenal_and_thyroid_disorders     0
# dtype: int64

# %%
# Computing Mean of every column.
columns_means = data.mean()
print(columns_means)
# Out:
# Patient_Number                   1000.50
# Blood_Pressure_Abnormality          0.49
# Level_of_Hemoglobin                11.71
# Genetic_Pedigree_Coefficient        0.49
# Age                                46.56
# BMI                                30.08
# Sex                                 0.50
# Pregnancy                           0.10
# Smoking                             0.51
# Physical_activity               25254.42
# salt_content_in_the_diet        24926.10
# alcohol_consumption_per_day       220.64
# Level_of_Stress                     2.01
# Chronic_kidney_disease              0.51
# Adrenal_and_thyroid_disorders       0.44
# dtype: float64

# %%
# Adding mean value in null spaces of column Genetic Preigree.
data['Genetic_Pedigree_Coefficient'] = data['Genetic_Pedigree_Coefficient'].fillna(0.49)

# %%
# Again Checking Null Values.
data.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Pregnancy                        0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
# Checking Data Types of every column.
data.dtypes
# Out:
# Patient_Number                     int64
# Blood_Pressure_Abnormality         int64
# Level_of_Hemoglobin              float64
# Genetic_Pedigree_Coefficient     float64
# Age                                int64
# BMI                                int64
# Sex                                int64
# Pregnancy                        float64
# Smoking                            int64
# Physical_activity                  int64
# salt_content_in_the_diet           int64
# alcohol_consumption_per_day      float64
# Level_of_Stress                    int64
# Chronic_kidney_disease             int64
# Adrenal_and_thyroid_disorders      int64
# dtype: object

# %%
# Dropping Unnecessary Column.
data.drop('Patient_Number',axis=1,inplace=True)

# %%
X = data.loc[:, data.columns != 'Blood_Pressure_Abnormality']     # All columns except target variable.
y = data[['Blood_Pressure_Abnormality']]                          # Target Variable.

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
X_scaled.head()
# Out:
#    Level_of_Hemoglobin  Genetic_Pedigree_Coefficient   Age   BMI   Sex  \
# 0                -0.20                          1.42 -0.73 -0.60  1.01
# 1                -0.90                         -0.93  0.44  0.25  1.01
# 2                -0.42                          1.46  1.37  1.61 -0.99
# 3                -0.32                         -0.23  1.43  1.69 -0.99
# 4                 1.13                          1.18  0.32 -0.94 -0.99
#
#    Pregnancy  Smoking  Physical_activity  salt_content_in_the_diet  \
# 0       3.01    -1.02               1.48                      1.63
# 1      -0.33    -1.02               0.06                      0.03
# 2      -0.33    -1.02              -1.09                      0.32
# 3      -0.33    -1.02              -1.04                     -1.23
# 4      -0.33    -1.02              -0.69                      1.74
#
#    alcohol_consumption_per_day  Level_of_Stress  Chronic_kidney_disease  \
# 0                        -1.40            -0.02                    0.99
# 1                        -0.10             1.20                   -1.01
# 2                        -0.98            -0.02                    0.99
# 3                         0.14            -1.23                    0.99
# 4                         1.12            -0.02                   -1.01
#
#    Adrenal_and_thyroid_disorders
# 0                           1.12
# 1                          -0.89
# 2                          -0.89
# 3                          -0.89
# 4                          -0.89

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 13)
# (1400, 1)
# (600, 13)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  5.90it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.90               0.90     0.90      0.90
# XGBClassifier                      0.90               0.90     0.90      0.90
# RandomForestClassifier             0.89               0.89     0.89      0.89
# BaggingClassifier                  0.87               0.87     0.87      0.87
# AdaBoostClassifier                 0.86               0.87     0.87      0.86
# SVC                                0.86               0.86     0.86      0.86
# NuSVC                              0.85               0.85     0.85      0.85
# GaussianNB                         0.83               0.83     0.83      0.83
# ExtraTreesClassifier               0.83               0.83     0.83      0.83
# DecisionTreeClassifier             0.82               0.82     0.82      0.82
# QuadraticDiscriminantAnalysis      0.81               0.81     0.81      0.81
# ExtraTreeClassifier                0.74               0.74     0.74      0.74
# KNeighborsClassifier               0.73               0.73     0.73      0.73
# CalibratedClassifierCV             0.70               0.70     0.70      0.70
# RidgeClassifierCV                  0.70               0.70     0.70      0.70
# RidgeClassifier                    0.70               0.70     0.70      0.70
# LinearSVC                          0.70               0.70     0.70      0.70
# LinearDiscriminantAnalysis         0.70               0.70     0.70      0.70
# LogisticRegression                 0.69               0.70     0.70      0.69
# LabelSpreading                     0.69               0.69     0.69      0.69
# LabelPropagation                   0.69               0.69     0.69      0.69
# BernoulliNB                        0.69               0.69     0.69      0.69
# NearestCentroid                    0.69               0.69     0.69      0.69
# Perceptron                         0.68               0.68     0.68      0.68
# SGDClassifier                      0.67               0.67     0.67      0.67
# PassiveAggressiveClassifier        0.65               0.65     0.65      0.65
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# LGBMClassifier                       0.19
# XGBClassifier                        0.31
# RandomForestClassifier               0.46
# BaggingClassifier                    0.20
# AdaBoostClassifier                   0.66
# SVC                                  0.17
# NuSVC                                0.22
# GaussianNB                           0.03
# ExtraTreesClassifier                 0.59
# DecisionTreeClassifier               0.08
# QuadraticDiscriminantAnalysis        0.02
# ExtraTreeClassifier                  0.06
# KNeighborsClassifier                 0.11
# CalibratedClassifierCV               0.65
# RidgeClassifierCV                    0.06
# RidgeClassifier                      0.03
# LinearSVC                            0.09
# LinearDiscriminantAnalysis           0.11
# LogisticRegression                   0.06
# LabelSpreading                       0.32
# LabelPropagation                     0.24
# BernoulliNB                          0.04
# NearestCentroid                      0.04
# Perceptron                           0.02
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.02
# DummyClassifier                      0.04

# %% [markdown]
# ### Dimensionality Reduction Algorithms

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=8)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5', 'principal component 6','principal component 7', 'principal component 8'])

# %%
PCA_Df.shape
# Out:
# (2000, 8)

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 8)
# (1400, 1)
# (600, 8)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:04<00:00,  6.04it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# RandomForestClassifier             0.76               0.76     0.76      0.76
# NuSVC                              0.76               0.76     0.76      0.76
# QuadraticDiscriminantAnalysis      0.75               0.75     0.75      0.75
# XGBClassifier                      0.74               0.75     0.75      0.74
# AdaBoostClassifier                 0.74               0.74     0.74      0.74
# SVC                                0.74               0.74     0.74      0.74
# LGBMClassifier                     0.73               0.74     0.74      0.73
# GaussianNB                         0.73               0.73     0.73      0.73
# BaggingClassifier                  0.73               0.73     0.73      0.73
# KNeighborsClassifier               0.72               0.72     0.72      0.72
# DecisionTreeClassifier             0.69               0.70     0.70      0.70
# RidgeClassifierCV                  0.69               0.69     0.69      0.69
# RidgeClassifier                    0.69               0.69     0.69      0.69
# LinearSVC                          0.69               0.69     0.69      0.69
# LinearDiscriminantAnalysis         0.69               0.69     0.69      0.69
# CalibratedClassifierCV             0.69               0.69     0.69      0.69
# LogisticRegression                 0.69               0.69     0.69      0.69
# NearestCentroid                    0.68               0.68     0.68      0.68
# BernoulliNB                        0.67               0.67     0.67      0.67
# LabelPropagation                   0.66               0.66     0.66      0.66
# PassiveAggressiveClassifier        0.66               0.66     0.66      0.66
# LabelSpreading                     0.66               0.66     0.66      0.66
# SGDClassifier                      0.64               0.64     0.64      0.64
# Perceptron                         0.63               0.63     0.63      0.63
# ExtraTreeClassifier                0.60               0.60     0.60      0.60
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.58
# RandomForestClassifier               0.62
# NuSVC                                0.24
# QuadraticDiscriminantAnalysis        0.03
# XGBClassifier                        0.34
# AdaBoostClassifier                   0.63
# SVC                                  0.22
# LGBMClassifier                       0.21
# GaussianNB                           0.03
# BaggingClassifier                    0.26
# KNeighborsClassifier                 0.11
# DecisionTreeClassifier               0.35
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.03
# LinearSVC                            0.09
# LinearDiscriminantAnalysis           0.04
# CalibratedClassifierCV               0.32
# LogisticRegression                   0.08
# NearestCentroid                      0.01
# BernoulliNB                          0.03
# LabelPropagation                     0.15
# PassiveAggressiveClassifier          0.02
# LabelSpreading                       0.22
# SGDClassifier                        0.02
# Perceptron                           0.03
# ExtraTreeClassifier                  0.03
# DummyClassifier                      0.03

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 1)
# (1400, 1)
# (600, 1)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 12.79it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.71               0.71     0.71      0.71
# Perceptron                         0.71               0.71     0.71      0.71
# NearestCentroid                    0.71               0.71     0.71      0.71
# KNeighborsClassifier               0.70               0.71     0.71      0.70
# LGBMClassifier                     0.70               0.70     0.70      0.70
# RidgeClassifierCV                  0.70               0.70     0.70      0.70
# RidgeClassifier                    0.70               0.70     0.70      0.70
# LogisticRegression                 0.70               0.70     0.70      0.70
# LinearDiscriminantAnalysis         0.70               0.70     0.70      0.70
# LinearSVC                          0.70               0.70     0.70      0.70
# GaussianNB                         0.70               0.70     0.70      0.70
# QuadraticDiscriminantAnalysis      0.70               0.70     0.70      0.70
# CalibratedClassifierCV             0.70               0.70     0.70      0.70
# SGDClassifier                      0.70               0.70     0.70      0.70
# XGBClassifier                      0.70               0.70     0.70      0.70
# PassiveAggressiveClassifier        0.70               0.70     0.70      0.70
# AdaBoostClassifier                 0.69               0.70     0.70      0.69
# ExtraTreeClassifier                0.69               0.69     0.69      0.69
# SVC                                0.69               0.69     0.69      0.69
# ExtraTreesClassifier               0.69               0.69     0.69      0.69
# BaggingClassifier                  0.69               0.69     0.69      0.68
# LabelPropagation                   0.68               0.69     0.69      0.68
# DecisionTreeClassifier             0.68               0.68     0.68      0.68
# RandomForestClassifier             0.68               0.68     0.68      0.68
# LabelSpreading                     0.68               0.68     0.68      0.68
# NuSVC                              0.54               0.54     0.54      0.54
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# BernoulliNB                          0.01
# Perceptron                           0.01
# NearestCentroid                      0.02
# KNeighborsClassifier                 0.04
# LGBMClassifier                       0.16
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# LogisticRegression                   0.02
# LinearDiscriminantAnalysis           0.02
# LinearSVC                            0.02
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.04
# CalibratedClassifierCV               0.06
# SGDClassifier                        0.02
# XGBClassifier                        0.19
# PassiveAggressiveClassifier          0.02
# AdaBoostClassifier                   0.19
# ExtraTreeClassifier                  0.02
# SVC                                  0.14
# ExtraTreesClassifier                 0.34
# BaggingClassifier                    0.07
# LabelPropagation                     0.10
# DecisionTreeClassifier               0.02
# RandomForestClassifier               0.34
# LabelSpreading                       0.15
# NuSVC                                0.18
# DummyClassifier                      0.02

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 2)
# (1400, 1)
# (600, 2)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 10.00it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelSpreading                     0.74               0.74     0.74      0.74
# KNeighborsClassifier               0.73               0.73     0.73      0.73
# LabelPropagation                   0.73               0.73     0.73      0.73
# RandomForestClassifier             0.71               0.72     0.72      0.71
# ExtraTreesClassifier               0.71               0.71     0.71      0.71
# XGBClassifier                      0.70               0.70     0.70      0.70
# BaggingClassifier                  0.69               0.69     0.69      0.69
# LGBMClassifier                     0.69               0.69     0.69      0.69
# SVC                                0.68               0.68     0.68      0.68
# DecisionTreeClassifier             0.68               0.68     0.68      0.68
# ExtraTreeClassifier                0.67               0.67     0.67      0.67
# AdaBoostClassifier                 0.66               0.66     0.66      0.66
# NearestCentroid                    0.65               0.65     0.65      0.64
# LinearDiscriminantAnalysis         0.64               0.64     0.64      0.64
# RidgeClassifier                    0.64               0.64     0.64      0.64
# RidgeClassifierCV                  0.64               0.64     0.64      0.64
# LinearSVC                          0.64               0.64     0.64      0.64
# LogisticRegression                 0.64               0.64     0.64      0.64
# CalibratedClassifierCV             0.64               0.64     0.64      0.64
# GaussianNB                         0.62               0.62     0.62      0.62
# QuadraticDiscriminantAnalysis      0.62               0.62     0.62      0.62
# SGDClassifier                      0.61               0.62     0.62      0.61
# NuSVC                              0.60               0.61     0.61      0.61
# BernoulliNB                        0.60               0.60     0.60      0.60
# PassiveAggressiveClassifier        0.54               0.53     0.53      0.52
# DummyClassifier                    0.49               0.50     0.50      0.32
# Perceptron                         0.47               0.46     0.46      0.42
#
#                                Time Taken
# Model
# LabelSpreading                       0.35
# KNeighborsClassifier                 0.06
# LabelPropagation                     0.14
# RandomForestClassifier               0.40
# ExtraTreesClassifier                 0.33
# XGBClassifier                        0.20
# BaggingClassifier                    0.07
# LGBMClassifier                       0.14
# SVC                                  0.16
# DecisionTreeClassifier               0.02
# ExtraTreeClassifier                  0.02
# AdaBoostClassifier                   0.32
# NearestCentroid                      0.02
# LinearDiscriminantAnalysis           0.03
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.02
# LinearSVC                            0.04
# LogisticRegression                   0.03
# CalibratedClassifierCV               0.08
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.02
# SGDClassifier                        0.02
# NuSVC                                0.29
# BernoulliNB                          0.02
# PassiveAggressiveClassifier          0.02
# DummyClassifier                      0.02
# Perceptron                           0.02

# %% [markdown]
# ### Singular Value Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=8)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 8)
# (1400, 1)
# (600, 8)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00,  9.75it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# RandomForestClassifier             0.76               0.76     0.76      0.76
# NuSVC                              0.76               0.76     0.76      0.76
# QuadraticDiscriminantAnalysis      0.75               0.75     0.75      0.75
# XGBClassifier                      0.74               0.75     0.75      0.74
# AdaBoostClassifier                 0.74               0.74     0.74      0.74
# SVC                                0.74               0.74     0.74      0.74
# LGBMClassifier                     0.73               0.74     0.74      0.73
# GaussianNB                         0.73               0.73     0.73      0.73
# BaggingClassifier                  0.73               0.73     0.73      0.73
# KNeighborsClassifier               0.72               0.72     0.72      0.72
# DecisionTreeClassifier             0.69               0.70     0.70      0.70
# RidgeClassifierCV                  0.69               0.69     0.69      0.69
# RidgeClassifier                    0.69               0.69     0.69      0.69
# LinearSVC                          0.69               0.69     0.69      0.69
# LinearDiscriminantAnalysis         0.69               0.69     0.69      0.69
# CalibratedClassifierCV             0.69               0.69     0.69      0.69
# LogisticRegression                 0.69               0.69     0.69      0.69
# NearestCentroid                    0.68               0.68     0.68      0.68
# BernoulliNB                        0.67               0.67     0.67      0.67
# LabelPropagation                   0.66               0.66     0.66      0.66
# PassiveAggressiveClassifier        0.66               0.66     0.66      0.66
# LabelSpreading                     0.66               0.66     0.66      0.66
# SGDClassifier                      0.64               0.64     0.64      0.64
# Perceptron                         0.63               0.63     0.63      0.63
# ExtraTreeClassifier                0.60               0.60     0.60      0.60
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.34
# RandomForestClassifier               0.45
# NuSVC                                0.18
# QuadraticDiscriminantAnalysis        0.02
# XGBClassifier                        0.33
# AdaBoostClassifier                   0.25
# SVC                                  0.16
# LGBMClassifier                       0.18
# GaussianNB                           0.02
# BaggingClassifier                    0.12
# KNeighborsClassifier                 0.07
# DecisionTreeClassifier               0.07
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# LinearSVC                            0.05
# LinearDiscriminantAnalysis           0.02
# CalibratedClassifierCV               0.16
# LogisticRegression                   0.02
# NearestCentroid                      0.01
# BernoulliNB                          0.02
# LabelPropagation                     0.11
# PassiveAggressiveClassifier          0.02
# LabelSpreading                       0.17
# SGDClassifier                        0.03
# Perceptron                           0.02
# ExtraTreeClassifier                  0.02
# DummyClassifier                      0.03

# %% [markdown]
# ### ISOMAP Embedding

# %%
from sklearn.manifold import Isomap
model = Isomap(n_components=2, n_neighbors=3)
# fit and transform the data
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (1400, 2)
# (1400, 1)
# (600, 2)
# (600, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 10.48it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelSpreading                     0.66               0.66     0.66      0.66
# LabelPropagation                   0.66               0.66     0.66      0.66
# KNeighborsClassifier               0.64               0.64     0.64      0.64
# BaggingClassifier                  0.64               0.64     0.64      0.63
# LGBMClassifier                     0.63               0.63     0.63      0.63
# SVC                                0.63               0.63     0.63      0.63
# PassiveAggressiveClassifier        0.64               0.63     0.63      0.63
# XGBClassifier                      0.63               0.63     0.63      0.63
# CalibratedClassifierCV             0.63               0.63     0.63      0.63
# LogisticRegression                 0.63               0.63     0.63      0.63
# RidgeClassifierCV                  0.63               0.63     0.63      0.63
# RidgeClassifier                    0.63               0.63     0.63      0.63
# LinearSVC                          0.63               0.63     0.63      0.63
# LinearDiscriminantAnalysis         0.63               0.63     0.63      0.63
# NearestCentroid                    0.63               0.63     0.63      0.62
# SGDClassifier                      0.63               0.62     0.62      0.62
# AdaBoostClassifier                 0.62               0.62     0.62      0.62
# RandomForestClassifier             0.62               0.62     0.62      0.62
# BernoulliNB                        0.62               0.62     0.62      0.62
# ExtraTreesClassifier               0.62               0.62     0.62      0.62
# GaussianNB                         0.62               0.62     0.62      0.62
# QuadraticDiscriminantAnalysis      0.61               0.62     0.62      0.62
# NuSVC                              0.61               0.61     0.61      0.61
# DecisionTreeClassifier             0.59               0.59     0.59      0.59
# ExtraTreeClassifier                0.59               0.59     0.59      0.59
# DummyClassifier                    0.49               0.50     0.50      0.32
# Perceptron                         0.50               0.49     0.49      0.42
#
#                                Time Taken
# Model
# LabelSpreading                       0.17
# LabelPropagation                     0.11
# KNeighborsClassifier                 0.04
# BaggingClassifier                    0.10
# LGBMClassifier                       0.14
# SVC                                  0.18
# PassiveAggressiveClassifier          0.02
# XGBClassifier                        0.20
# CalibratedClassifierCV               0.15
# LogisticRegression                   0.03
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# LinearSVC                            0.03
# LinearDiscriminantAnalysis           0.02
# NearestCentroid                      0.01
# SGDClassifier                        0.02
# AdaBoostClassifier                   0.28
# RandomForestClassifier               0.38
# BernoulliNB                          0.02
# ExtraTreesClassifier                 0.44
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.02
# NuSVC                                0.22
# DecisionTreeClassifier               0.04
# ExtraTreeClassifier                  0.02
# DummyClassifier                      0.03
# Perceptron                           0.02

# %% [markdown]
# ## Dataset 3: Cardiovascular Disease

# %% [markdown]
# Dataset Info : Dataset we are using in this case study is  named as “cardiovascular disease prediction” and contains medical information of patients. Dataset contains 70000 patients records and 13 features. We are using “cardio” as our target variable. It is a Binary class classification problem, where value of class is 0 and 1 (0 means disease not detected and 1 means disease 2 means detected). Dataset is balanced and consist of 14 attributes other than target attribute. Dataset is cleaned and does not contain any null values or string column, so we don’t need much data prepossessing.

# %%
data = pd.read_csv("E:/cardio_disease.csv", sep=';')
data.shape
# Out:
# (70000, 13)

# %% [markdown]
# #### Data Preprocessing

# %%
# Counting Number of distribution.
dictribution = data["cardio"].value_counts()
dictribution
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
# Checking Data Types of every column.
data.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
# Dropping Unnecessary Column.
data.drop('id',axis=1,inplace=True)

# %%
X = data.loc[:, data.columns != 'cardio']     # All columns except target variable.
y = data[['cardio']]                          # Target Variable.

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (49000, 11)
# (49000, 1)
# (21000, 11)
# (21000, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [49:57<00:00, 103.38s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.73               0.73     0.73      0.73
# XGBClassifier                      0.73               0.73     0.73      0.73
# AdaBoostClassifier                 0.73               0.73     0.73      0.73
# SVC                                0.73               0.73     0.73      0.73
# LogisticRegression                 0.72               0.72     0.72      0.72
# SGDClassifier                      0.72               0.72     0.72      0.72
# RandomForestClassifier             0.72               0.72     0.72      0.72
# LinearSVC                          0.71               0.71     0.71      0.71
# BernoulliNB                        0.71               0.71     0.71      0.71
# CalibratedClassifierCV             0.71               0.71     0.71      0.71
# ExtraTreesClassifier               0.70               0.70     0.70      0.70
# BaggingClassifier                  0.69               0.69     0.69      0.69
# Perceptron                         0.67               0.67     0.67      0.67
# PassiveAggressiveClassifier        0.67               0.67     0.67      0.66
# NuSVC                              0.66               0.66     0.66      0.66
# KNeighborsClassifier               0.65               0.65     0.65      0.65
# LinearDiscriminantAnalysis         0.65               0.65     0.65      0.65
# RidgeClassifier                    0.65               0.65     0.65      0.65
# RidgeClassifierCV                  0.65               0.65     0.65      0.65
# NearestCentroid                    0.65               0.65     0.65      0.64
# DecisionTreeClassifier             0.64               0.64     0.64      0.64
# ExtraTreeClassifier                0.63               0.63     0.63      0.63
# GaussianNB                         0.59               0.59     0.59      0.53
# QuadraticDiscriminantAnalysis      0.58               0.58     0.58      0.53
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.65
# XGBClassifier                        4.18
# AdaBoostClassifier                   2.63
# SVC                                254.04
# LogisticRegression                   0.20
# SGDClassifier                        0.38
# RandomForestClassifier               9.18
# LinearSVC                           12.92
# BernoulliNB                          0.12
# CalibratedClassifierCV              47.43
# ExtraTreesClassifier                 9.22
# BaggingClassifier                    3.01
# Perceptron                           0.15
# PassiveAggressiveClassifier          0.19
# NuSVC                             2637.70
# KNeighborsClassifier                14.37
# LinearDiscriminantAnalysis           0.18
# RidgeClassifier                      0.13
# RidgeClassifierCV                    0.17
# NearestCentroid                      0.09
# DecisionTreeClassifier               0.41
# ExtraTreeClassifier                  0.16
# GaussianNB                           0.11
# QuadraticDiscriminantAnalysis        0.12
# DummyClassifier                      0.07

# %% [markdown]
# ### Dimensionality Reduction Algorithm

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (49000, 5)
# (49000, 1)
# (21000, 5)
# (21000, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [15:53<00:00, 32.88s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.71               0.71     0.71      0.71
# XGBClassifier                      0.71               0.71     0.71      0.71
# SVC                                0.70               0.70     0.70      0.70
# RandomForestClassifier             0.70               0.70     0.70      0.70
# ExtraTreesClassifier               0.69               0.69     0.69      0.69
# KNeighborsClassifier               0.68               0.68     0.68      0.68
# SGDClassifier                      0.68               0.68     0.68      0.68
# LogisticRegression                 0.68               0.68     0.68      0.68
# BaggingClassifier                  0.67               0.67     0.67      0.67
# AdaBoostClassifier                 0.67               0.67     0.67      0.67
# LinearSVC                          0.67               0.67     0.67      0.66
# CalibratedClassifierCV             0.67               0.66     0.66      0.66
# LinearDiscriminantAnalysis         0.64               0.64     0.64      0.63
# RidgeClassifier                    0.64               0.64     0.64      0.63
# RidgeClassifierCV                  0.64               0.64     0.64      0.63
# NearestCentroid                    0.64               0.64     0.64      0.63
# PassiveAggressiveClassifier        0.63               0.63     0.63      0.63
# BernoulliNB                        0.62               0.62     0.62      0.62
# DecisionTreeClassifier             0.62               0.62     0.62      0.62
# ExtraTreeClassifier                0.61               0.61     0.61      0.61
# NuSVC                              0.59               0.59     0.59      0.59
# GaussianNB                         0.58               0.58     0.58      0.55
# QuadraticDiscriminantAnalysis      0.58               0.58     0.58      0.54
# Perceptron                         0.57               0.57     0.57      0.57
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.61
# XGBClassifier                        6.59
# SVC                                199.13
# RandomForestClassifier              15.44
# ExtraTreesClassifier                 8.51
# KNeighborsClassifier                 1.12
# SGDClassifier                        0.15
# LogisticRegression                   0.09
# BaggingClassifier                    3.34
# AdaBoostClassifier                   2.96
# LinearSVC                            9.47
# CalibratedClassifierCV              34.65
# LinearDiscriminantAnalysis           0.10
# RidgeClassifier                      0.07
# RidgeClassifierCV                    0.08
# NearestCentroid                      0.05
# PassiveAggressiveClassifier          0.10
# BernoulliNB                          0.06
# DecisionTreeClassifier               0.61
# ExtraTreeClassifier                  0.13
# NuSVC                              669.80
# GaussianNB                           0.06
# QuadraticDiscriminantAnalysis        0.06
# Perceptron                           0.09
# DummyClassifier                      0.05

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (49000, 1)
# (49000, 1)
# (21000, 1)
# (21000, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [09:02<00:00, 18.72s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.65               0.65     0.65      0.65
# CalibratedClassifierCV             0.65               0.65     0.65      0.65
# AdaBoostClassifier                 0.65               0.65     0.65      0.65
# LGBMClassifier                     0.65               0.65     0.65      0.65
# SGDClassifier                      0.65               0.65     0.65      0.65
# LinearSVC                          0.65               0.65     0.65      0.65
# SVC                                0.65               0.65     0.65      0.65
# RidgeClassifierCV                  0.65               0.65     0.65      0.65
# RidgeClassifier                    0.65               0.65     0.65      0.65
# LinearDiscriminantAnalysis         0.65               0.65     0.65      0.65
# NearestCentroid                    0.65               0.65     0.65      0.65
# Perceptron                         0.65               0.65     0.65      0.65
# BernoulliNB                        0.65               0.65     0.65      0.65
# XGBClassifier                      0.65               0.65     0.65      0.65
# QuadraticDiscriminantAnalysis      0.64               0.64     0.64      0.64
# GaussianNB                         0.64               0.64     0.64      0.64
# PassiveAggressiveClassifier        0.64               0.64     0.64      0.64
# KNeighborsClassifier               0.60               0.60     0.60      0.60
# BaggingClassifier                  0.57               0.57     0.57      0.57
# RandomForestClassifier             0.56               0.56     0.56      0.56
# DecisionTreeClassifier             0.56               0.56     0.56      0.56
# ExtraTreesClassifier               0.56               0.56     0.56      0.56
# ExtraTreeClassifier                0.56               0.56     0.56      0.56
# NuSVC                              0.51               0.51     0.51      0.51
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LogisticRegression                   0.05
# CalibratedClassifierCV              11.33
# AdaBoostClassifier                   1.49
# LGBMClassifier                       0.41
# SGDClassifier                        0.08
# LinearSVC                            3.76
# SVC                                227.18
# RidgeClassifierCV                    0.05
# RidgeClassifier                      0.04
# LinearDiscriminantAnalysis           0.05
# NearestCentroid                      0.03
# Perceptron                           0.06
# BernoulliNB                          0.05
# XGBClassifier                        3.86
# QuadraticDiscriminantAnalysis        0.04
# GaussianNB                           0.03
# PassiveAggressiveClassifier          0.06
# KNeighborsClassifier                 0.72
# BaggingClassifier                    1.99
# RandomForestClassifier              17.11
# DecisionTreeClassifier               0.32
# ExtraTreesClassifier                 7.53
# ExtraTreeClassifier                  0.10
# NuSVC                              266.42
# DummyClassifier                      0.03

# %% [markdown]
# ### Singular Vector Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (49000, 5)
# (49000, 1)
# (21000, 5)
# (21000, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [16:03<00:00, 33.23s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.71               0.71     0.71      0.71
# XGBClassifier                      0.71               0.71     0.71      0.71
# SVC                                0.70               0.70     0.70      0.70
# RandomForestClassifier             0.70               0.70     0.70      0.70
# ExtraTreesClassifier               0.69               0.69     0.69      0.69
# KNeighborsClassifier               0.68               0.68     0.68      0.68
# SGDClassifier                      0.68               0.68     0.68      0.68
# LogisticRegression                 0.68               0.68     0.68      0.68
# BaggingClassifier                  0.67               0.67     0.67      0.67
# AdaBoostClassifier                 0.67               0.67     0.67      0.67
# LinearSVC                          0.67               0.67     0.67      0.66
# CalibratedClassifierCV             0.67               0.66     0.66      0.66
# LinearDiscriminantAnalysis         0.64               0.64     0.64      0.63
# RidgeClassifier                    0.64               0.64     0.64      0.63
# RidgeClassifierCV                  0.64               0.64     0.64      0.63
# NearestCentroid                    0.64               0.64     0.64      0.63
# PassiveAggressiveClassifier        0.63               0.63     0.63      0.63
# BernoulliNB                        0.62               0.62     0.62      0.62
# DecisionTreeClassifier             0.62               0.62     0.62      0.62
# ExtraTreeClassifier                0.61               0.61     0.61      0.61
# NuSVC                              0.60               0.60     0.60      0.59
# GaussianNB                         0.58               0.58     0.58      0.55
# QuadraticDiscriminantAnalysis      0.58               0.58     0.58      0.54
# Perceptron                         0.57               0.57     0.57      0.57
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.53
# XGBClassifier                        6.48
# SVC                                194.61
# RandomForestClassifier              15.51
# ExtraTreesClassifier                 8.64
# KNeighborsClassifier                 1.16
# SGDClassifier                        0.16
# LogisticRegression                   0.10
# BaggingClassifier                    3.44
# AdaBoostClassifier                   3.03
# LinearSVC                           10.60
# CalibratedClassifierCV              32.49
# LinearDiscriminantAnalysis           0.11
# RidgeClassifier                      0.07
# RidgeClassifierCV                    0.10
# NearestCentroid                      0.06
# PassiveAggressiveClassifier          0.10
# BernoulliNB                          0.07
# DecisionTreeClassifier               0.57
# ExtraTreeClassifier                  0.13
# NuSVC                              685.25
# GaussianNB                           0.07
# QuadraticDiscriminantAnalysis        0.07
# Perceptron                           0.10
# DummyClassifier                      0.06

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (49000, 2)
# (49000, 1)
# (21000, 2)
# (21000, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [09:04<00:00, 18.78s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.64               0.64     0.64      0.64
# XGBClassifier                      0.63               0.63     0.63      0.63
# KNeighborsClassifier               0.62               0.62     0.62      0.62
# RandomForestClassifier             0.61               0.61     0.61      0.61
# SVC                                0.61               0.61     0.61      0.61
# ExtraTreesClassifier               0.61               0.61     0.61      0.61
# BaggingClassifier                  0.60               0.60     0.60      0.60
# AdaBoostClassifier                 0.60               0.60     0.60      0.60
# DecisionTreeClassifier             0.58               0.58     0.58      0.58
# ExtraTreeClassifier                0.58               0.58     0.58      0.58
# QuadraticDiscriminantAnalysis      0.57               0.57     0.57      0.57
# GaussianNB                         0.57               0.57     0.57      0.56
# LogisticRegression                 0.56               0.56     0.56      0.56
# CalibratedClassifierCV             0.56               0.56     0.56      0.56
# LinearSVC                          0.56               0.56     0.56      0.56
# LinearDiscriminantAnalysis         0.56               0.56     0.56      0.56
# RidgeClassifier                    0.56               0.56     0.56      0.56
# RidgeClassifierCV                  0.56               0.56     0.56      0.56
# NearestCentroid                    0.56               0.56     0.56      0.56
# BernoulliNB                        0.55               0.55     0.55      0.55
# SGDClassifier                      0.54               0.54     0.54      0.53
# NuSVC                              0.51               0.51     0.51      0.51
# DummyClassifier                    0.50               0.50     0.50      0.33
# PassiveAggressiveClassifier        0.46               0.46     0.46      0.41
# Perceptron                         0.46               0.46     0.46      0.46
#
#                                Time Taken
# Model
# LGBMClassifier                       0.41
# XGBClassifier                        3.84
# KNeighborsClassifier                 0.77
# RandomForestClassifier              11.37
# SVC                                219.31
# ExtraTreesClassifier                 7.25
# BaggingClassifier                    1.73
# AdaBoostClassifier                   1.68
# DecisionTreeClassifier               0.30
# ExtraTreeClassifier                  0.11
# QuadraticDiscriminantAnalysis        0.41
# GaussianNB                           0.06
# LogisticRegression                   0.08
# CalibratedClassifierCV               2.12
# LinearSVC                            0.94
# LinearDiscriminantAnalysis           0.13
# RidgeClassifier                      0.10
# RidgeClassifierCV                    0.08
# NearestCentroid                      0.05
# BernoulliNB                          0.05
# SGDClassifier                        0.11
# NuSVC                              284.18
# DummyClassifier                      0.04
# PassiveAggressiveClassifier          0.09
# Perceptron                           0.07

# %% [markdown]
# ## Dataset 4 : Heart Disease Prediction

# %% [markdown]
# Dataset Info :
#
# This datset is take from UCI Machine learning repository. Its a binary class classififcation dataset.
# link for data : https://archive.ics.uci.edu/ml/datasets/heart+disease

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:/heart_2020.csv")
data.shape
# Out:
# (319795, 18)

# %%
data = data.sample(20000)
data.shape
# Out:
# (20000, 18)

# %%
data.head(5)
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 251961           No  24.41     Yes              No     No             0.0
# 5347             No  26.63     Yes             Yes     No            21.0
# 316653           No  27.40      No             Yes     No             0.0
# 103705           No  20.18      No              No     No             0.0
# 288584           No  27.99      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex AgeCategory  \
# 251961           0.0          No  Female       75-79
# 5347            21.0          No  Female       25-29
# 316653          30.0          No  Female       30-34
# 103705          15.0          No  Female       18-24
# 288584           5.0          No  Female       70-74
#
#                                   Race Diabetic PhysicalActivity  GenHealth  \
# 251961                        Hispanic       No              Yes  Excellent
# 5347    American Indian/Alaskan Native       No               No       Good
# 316653                        Hispanic       No              Yes  Very good
# 103705                           White       No              Yes       Good
# 288584                           White       No              Yes  Excellent
#
#         SleepTime Asthma KidneyDisease SkinCancer
# 251961        6.0     No            No         No
# 5347          3.0     No            No         No
# 316653        5.0     No            No         No
# 103705        8.0    Yes            No         No
# 288584        7.0     No            No         No

# %%
data.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 251961 to 72269
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      20000 non-null  object
#  1   BMI               20000 non-null  float64
#  2   Smoking           20000 non-null  object
#  3   AlcoholDrinking   20000 non-null  object
#  4   Stroke            20000 non-null  object
#  5   PhysicalHealth    20000 non-null  float64
#  6   MentalHealth      20000 non-null  float64
#  7   DiffWalking       20000 non-null  object
#  8   Sex               20000 non-null  object
#  9   AgeCategory       20000 non-null  object
#  10  Race              20000 non-null  object
#  11  Diabetic          20000 non-null  object
#  12  PhysicalActivity  20000 non-null  object
#  13  GenHealth         20000 non-null  object
#  14  SleepTime         20000 non-null  float64
#  15  Asthma            20000 non-null  object
#  16  KidneyDisease     20000 non-null  object
#  17  SkinCancer        20000 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 2.9+ MB

# %%
data['AgeCategory'].unique()
# Out:
# array(['75-79', '25-29', '30-34', '18-24', '70-74', '40-44', '50-54',
#        '55-59', '65-69', '35-39', '60-64', '45-49', '80 or older'],
#       dtype=object)

# %%
data['Age'] = data['AgeCategory'].str[:2]
data['Age'] = pd.to_numeric(data['Age'])

# %%
data.drop('AgeCategory',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()                                 #encode the education column
label=le.fit_transform(data['HeartDisease'])
label
data.drop('HeartDisease',axis=1)
data['HeartDisease']=label

label1=le.fit_transform(data['Smoking'])   #encode the marital_Status column
data.drop('Smoking',axis=1)
data['Smoking']=label1
data

label1=le.fit_transform(data['AlcoholDrinking'])   #encode the marital_Status column
data.drop('AlcoholDrinking',axis=1)
data['AlcoholDrinking']=label1
data

label1=le.fit_transform(data['Stroke'])   #encode the marital_Status column
data.drop('Stroke',axis=1)
data['Stroke']=label1
data

label1=le.fit_transform(data['DiffWalking'])   #encode the marital_Status column
data.drop('DiffWalking',axis=1)
data['DiffWalking']=label1
data

label1=le.fit_transform(data['Sex'])   #encode the marital_Status column
data.drop('Sex',axis=1)
data['Sex']=label1

label1=le.fit_transform(data['Race'])   #encode the marital_Status column
data.drop('Race',axis=1)
data['Race']=label1

label1=le.fit_transform(data['Diabetic'])   #encode the marital_Status column
data.drop('Diabetic',axis=1)
data['Diabetic']=label1

label1=le.fit_transform(data['PhysicalActivity'])   #encode the marital_Status column
data.drop('Diabetic',axis=1)
data['Diabetic']=label1


label1=le.fit_transform(data['GenHealth'])   #encode the marital_Status column
data.drop('GenHealth',axis=1)
data['GenHealth']=label1


label1=le.fit_transform(data['Asthma'])   #encode the marital_Status column
data.drop('Asthma',axis=1)
data['Asthma']=label1

label1=le.fit_transform(data['KidneyDisease'])   #encode the marital_Status column
data.drop('KidneyDisease',axis=1)
data['KidneyDisease']=label1

label1=le.fit_transform(data['SkinCancer'])   #encode the marital_Status column
data.drop('SkinCancer',axis=1)
data['SkinCancer']=label1

label1=le.fit_transform(data['PhysicalActivity'])   #encode the marital_Status column
data.drop('PhysicalActivity',axis=1)
data['PhysicalActivity']=label1

# %%
data.dtypes
# Out:
# HeartDisease          int32
# BMI                 float64
# Smoking               int32
# AlcoholDrinking       int32
# Stroke                int32
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking           int32
# Sex                   int32
# Race                  int32
# Diabetic              int32
# PhysicalActivity      int32
# GenHealth             int32
# SleepTime           float64
# Asthma                int32
# KidneyDisease         int32
# SkinCancer            int32
# Age                   int64
# dtype: object

# %%
X = data.loc[:, data.columns != 'HeartDisease']     # All columns except target variable.
y = data['HeartDisease']                        # Target Variable.

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (14000, 17)
# (14000,)
# (6000, 17)
# (6000,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:59<00:00,  2.06s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.79               0.71     0.71      0.83
# GaussianNB                         0.85               0.67     0.67      0.87
# Perceptron                         0.79               0.65     0.65      0.83
# QuadraticDiscriminantAnalysis      0.57               0.63     0.63      0.66
# BernoulliNB                        0.89               0.61     0.61      0.89
# LinearDiscriminantAnalysis         0.91               0.58     0.58      0.90
# DecisionTreeClassifier             0.87               0.58     0.58      0.87
# ExtraTreeClassifier                0.87               0.58     0.58      0.87
# LabelSpreading                     0.88               0.57     0.57      0.87
# LabelPropagation                   0.88               0.57     0.57      0.87
# XGBClassifier                      0.91               0.55     0.55      0.89
# KNeighborsClassifier               0.91               0.55     0.55      0.89
# CalibratedClassifierCV             0.92               0.55     0.55      0.89
# AdaBoostClassifier                 0.92               0.55     0.55      0.89
# ExtraTreesClassifier               0.91               0.55     0.55      0.89
# LogisticRegression                 0.92               0.54     0.54      0.89
# BaggingClassifier                  0.90               0.54     0.54      0.88
# LGBMClassifier                     0.91               0.54     0.54      0.89
# PassiveAggressiveClassifier        0.91               0.53     0.53      0.88
# RandomForestClassifier             0.91               0.53     0.53      0.89
# LinearSVC                          0.92               0.51     0.51      0.88
# SVC                                0.92               0.51     0.51      0.88
# RidgeClassifier                    0.92               0.51     0.51      0.88
# RidgeClassifierCV                  0.92               0.51     0.51      0.88
# SGDClassifier                      0.92               0.50     0.50      0.88
# DummyClassifier                    0.92               0.50     0.50      0.88
#
#                                Time Taken
# Model
# NearestCentroid                      0.03
# GaussianNB                           0.04
# Perceptron                           0.04
# QuadraticDiscriminantAnalysis        0.06
# BernoulliNB                          0.04
# LinearDiscriminantAnalysis           0.08
# DecisionTreeClassifier               0.09
# ExtraTreeClassifier                  0.05
# LabelSpreading                      20.39
# LabelPropagation                    14.81
# XGBClassifier                        1.43
# KNeighborsClassifier                 0.75
# CalibratedClassifierCV               5.14
# AdaBoostClassifier                   0.62
# ExtraTreesClassifier                 1.65
# LogisticRegression                   0.06
# BaggingClassifier                    0.48
# LGBMClassifier                       0.30
# PassiveAggressiveClassifier          0.06
# RandomForestClassifier               1.56
# LinearSVC                            1.52
# SVC                                 10.23
# RidgeClassifier                      0.10
# RidgeClassifierCV                    0.06
# SGDClassifier                        0.10
# DummyClassifier                      0.03

# %% [markdown]
# ### Dimensionality Reduction Algorithm

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
PCA_Df.shape
# Out:
# (20000, 5)

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (14000, 5)
# (14000,)
# (6000, 5)
# (6000,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:42<00:00,  1.47s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.78               0.71     0.71      0.83
# PassiveAggressiveClassifier        0.70               0.66     0.66      0.77
# QuadraticDiscriminantAnalysis      0.90               0.59     0.59      0.89
# GaussianNB                         0.91               0.58     0.58      0.89
# LinearDiscriminantAnalysis         0.91               0.57     0.57      0.90
# DecisionTreeClassifier             0.86               0.57     0.57      0.87
# ExtraTreeClassifier                0.87               0.56     0.56      0.87
# Perceptron                         0.72               0.56     0.56      0.78
# LabelSpreading                     0.90               0.56     0.56      0.89
# LabelPropagation                   0.90               0.56     0.56      0.88
# KNeighborsClassifier               0.91               0.54     0.54      0.89
# LogisticRegression                 0.92               0.54     0.54      0.89
# BaggingClassifier                  0.91               0.53     0.53      0.89
# CalibratedClassifierCV             0.92               0.53     0.53      0.89
# RandomForestClassifier             0.91               0.53     0.53      0.88
# AdaBoostClassifier                 0.92               0.53     0.53      0.89
# XGBClassifier                      0.91               0.52     0.52      0.88
# ExtraTreesClassifier               0.91               0.52     0.52      0.88
# LGBMClassifier                     0.91               0.52     0.52      0.88
# LinearSVC                          0.92               0.51     0.51      0.88
# SVC                                0.92               0.51     0.51      0.88
# RidgeClassifier                    0.92               0.50     0.50      0.88
# RidgeClassifierCV                  0.92               0.50     0.50      0.88
# DummyClassifier                    0.92               0.50     0.50      0.88
# SGDClassifier                      0.92               0.50     0.50      0.88
# BernoulliNB                        0.92               0.50     0.50      0.88
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# PassiveAggressiveClassifier          0.03
# QuadraticDiscriminantAnalysis        0.03
# GaussianNB                           0.02
# LinearDiscriminantAnalysis           0.04
# DecisionTreeClassifier               0.12
# ExtraTreeClassifier                  0.03
# Perceptron                           0.03
# LabelSpreading                      12.95
# LabelPropagation                     8.44
# KNeighborsClassifier                 0.37
# LogisticRegression                   0.04
# BaggingClassifier                    0.68
# CalibratedClassifierCV               2.40
# RandomForestClassifier               3.18
# AdaBoostClassifier                   0.90
# XGBClassifier                        2.10
# ExtraTreesClassifier                 1.38
# LGBMClassifier                       0.23
# LinearSVC                            0.64
# SVC                                  8.96
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.02
# SGDClassifier                        0.04
# BernoulliNB                          0.03

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (14000, 1)
# (14000,)
# (6000, 1)
# (6000,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:29<00:00,  1.01s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# PassiveAggressiveClassifier        0.79               0.72     0.72      0.83
# NearestCentroid                    0.81               0.71     0.71      0.84
# Perceptron                         0.85               0.68     0.68      0.87
# GaussianNB                         0.91               0.60     0.60      0.90
# QuadraticDiscriminantAnalysis      0.91               0.60     0.60      0.90
# LinearDiscriminantAnalysis         0.91               0.59     0.59      0.90
# ExtraTreesClassifier               0.87               0.57     0.57      0.87
# DecisionTreeClassifier             0.87               0.57     0.57      0.87
# RandomForestClassifier             0.87               0.57     0.57      0.87
# BaggingClassifier                  0.88               0.56     0.56      0.87
# CalibratedClassifierCV             0.92               0.56     0.56      0.90
# LogisticRegression                 0.92               0.56     0.56      0.90
# ExtraTreeClassifier                0.87               0.55     0.55      0.86
# AdaBoostClassifier                 0.92               0.55     0.55      0.89
# KNeighborsClassifier               0.91               0.54     0.54      0.89
# XGBClassifier                      0.92               0.54     0.54      0.89
# LGBMClassifier                     0.92               0.53     0.53      0.89
# LinearSVC                          0.92               0.52     0.52      0.89
# LabelSpreading                     0.92               0.51     0.51      0.88
# LabelPropagation                   0.92               0.51     0.51      0.88
# RidgeClassifier                    0.92               0.51     0.51      0.88
# RidgeClassifierCV                  0.92               0.51     0.51      0.88
# SVC                                0.92               0.51     0.51      0.88
# DummyClassifier                    0.92               0.50     0.50      0.88
# SGDClassifier                      0.92               0.50     0.50      0.88
# BernoulliNB                        0.92               0.50     0.50      0.88
#
#                                Time Taken
# Model
# PassiveAggressiveClassifier          0.02
# NearestCentroid                      0.02
# Perceptron                           0.02
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.02
# LinearDiscriminantAnalysis           0.02
# ExtraTreesClassifier                 1.38
# DecisionTreeClassifier               0.10
# RandomForestClassifier               2.35
# BaggingClassifier                    0.30
# CalibratedClassifierCV               1.48
# LogisticRegression                   0.03
# ExtraTreeClassifier                  0.04
# AdaBoostClassifier                   0.44
# KNeighborsClassifier                 0.28
# XGBClassifier                        1.10
# LGBMClassifier                       0.21
# LinearSVC                            0.30
# LabelSpreading                      10.63
# LabelPropagation                     6.47
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# SVC                                  3.90
# DummyClassifier                      0.03
# SGDClassifier                        0.03
# BernoulliNB                          0.03

# %% [markdown]
# ### Singular Value Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (14000, 5)
# (14000,)
# (6000, 5)
# (6000,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:43<00:00,  1.51s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.79               0.71     0.71      0.83
# Perceptron                         0.71               0.68     0.68      0.78
# PassiveAggressiveClassifier        0.69               0.66     0.66      0.76
# QuadraticDiscriminantAnalysis      0.90               0.59     0.59      0.89
# GaussianNB                         0.91               0.59     0.59      0.89
# LinearDiscriminantAnalysis         0.91               0.57     0.57      0.90
# ExtraTreeClassifier                0.86               0.57     0.57      0.87
# DecisionTreeClassifier             0.87               0.57     0.57      0.87
# LabelSpreading                     0.90               0.55     0.55      0.89
# LabelPropagation                   0.90               0.55     0.55      0.88
# KNeighborsClassifier               0.91               0.54     0.54      0.89
# LogisticRegression                 0.92               0.54     0.54      0.89
# CalibratedClassifierCV             0.92               0.53     0.53      0.89
# AdaBoostClassifier                 0.92               0.53     0.53      0.89
# RandomForestClassifier             0.91               0.53     0.53      0.88
# XGBClassifier                      0.91               0.53     0.53      0.88
# BaggingClassifier                  0.91               0.52     0.52      0.88
# ExtraTreesClassifier               0.91               0.52     0.52      0.88
# LGBMClassifier                     0.91               0.52     0.52      0.88
# LinearSVC                          0.92               0.51     0.51      0.88
# SVC                                0.92               0.51     0.51      0.88
# RidgeClassifier                    0.92               0.50     0.50      0.88
# RidgeClassifierCV                  0.92               0.50     0.50      0.88
# DummyClassifier                    0.92               0.50     0.50      0.88
# SGDClassifier                      0.92               0.50     0.50      0.88
# BernoulliNB                        0.92               0.50     0.50      0.88
#
#                                Time Taken
# Model
# NearestCentroid                      0.03
# Perceptron                           0.03
# PassiveAggressiveClassifier          0.03
# QuadraticDiscriminantAnalysis        0.03
# GaussianNB                           0.03
# LinearDiscriminantAnalysis           0.04
# ExtraTreeClassifier                  0.04
# DecisionTreeClassifier               0.14
# LabelSpreading                      13.14
# LabelPropagation                     8.69
# KNeighborsClassifier                 0.40
# LogisticRegression                   0.04
# CalibratedClassifierCV               2.56
# AdaBoostClassifier                   1.04
# RandomForestClassifier               3.19
# XGBClassifier                        1.88
# BaggingClassifier                    0.72
# ExtraTreesClassifier                 1.67
# LGBMClassifier                       0.23
# LinearSVC                            0.68
# SVC                                  8.89
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.02
# SGDClassifier                        0.05
# BernoulliNB                          0.03

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (14000, 2)
# (14000,)
# (6000, 2)
# (6000,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:43<00:00,  1.50s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.59               0.60     0.60      0.68
# ExtraTreeClassifier                0.87               0.56     0.56      0.87
# DecisionTreeClassifier             0.87               0.56     0.56      0.87
# BaggingClassifier                  0.90               0.55     0.55      0.88
# ExtraTreesClassifier               0.89               0.55     0.55      0.88
# RandomForestClassifier             0.90               0.55     0.55      0.88
# KNeighborsClassifier               0.91               0.54     0.54      0.89
# XGBClassifier                      0.91               0.52     0.52      0.88
# LGBMClassifier                     0.92               0.52     0.52      0.88
# AdaBoostClassifier                 0.92               0.51     0.51      0.88
# PassiveAggressiveClassifier        0.71               0.50     0.50      0.77
# LabelPropagation                   0.92               0.50     0.50      0.88
# LabelSpreading                     0.92               0.50     0.50      0.88
# LinearDiscriminantAnalysis         0.92               0.50     0.50      0.88
# GaussianNB                         0.92               0.50     0.50      0.88
# LogisticRegression                 0.92               0.50     0.50      0.88
# DummyClassifier                    0.92               0.50     0.50      0.88
# Perceptron                         0.92               0.50     0.50      0.88
# QuadraticDiscriminantAnalysis      0.92               0.50     0.50      0.88
# CalibratedClassifierCV             0.92               0.50     0.50      0.88
# RidgeClassifier                    0.92               0.50     0.50      0.88
# RidgeClassifierCV                  0.92               0.50     0.50      0.88
# SGDClassifier                      0.92               0.50     0.50      0.88
# SVC                                0.92               0.50     0.50      0.88
# BernoulliNB                        0.92               0.50     0.50      0.88
# LinearSVC                          0.92               0.50     0.50      0.88
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# ExtraTreeClassifier                  0.03
# DecisionTreeClassifier               0.07
# BaggingClassifier                    0.34
# ExtraTreesClassifier                 1.25
# RandomForestClassifier               2.12
# KNeighborsClassifier                 0.30
# XGBClassifier                        1.14
# LGBMClassifier                       0.21
# AdaBoostClassifier                   0.52
# PassiveAggressiveClassifier          0.03
# LabelPropagation                    10.75
# LabelSpreading                      22.52
# LinearDiscriminantAnalysis           0.03
# GaussianNB                           0.02
# LogisticRegression                   0.04
# DummyClassifier                      0.02
# Perceptron                           0.02
# QuadraticDiscriminantAnalysis        0.03
# CalibratedClassifierCV               0.43
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# SGDClassifier                        0.04
# SVC                                  3.45
# BernoulliNB                          0.02
# LinearSVC                            0.11

# %% [markdown]
# ## Dataset 5 : Credit Card Fraud Detection

# %% [markdown]
# Dataset Info : Dataset we are using in this case study is  named as “Credit Card dataset” and contains information of peopl2. Dataset contains 284807 records and 31 features. We are using “class” as our target variable. It is a Binary class classification problem, where value of class is 0 and 1 (0 means fraud not detected and 1 means detected). Dataset is imbalanced and consist of 31 attributes other than target attribute.

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:/creditcard.csv")
data.shape
# Out:
# (284807, 31)

# %%
data.head()
# Out:
#    Time    V1    V2   V3    V4    V5    V6    V7    V8    V9  ...   V21   V22  \
# 0  0.00 -1.36 -0.07 2.54  1.38 -0.34  0.46  0.24  0.10  0.36  ... -0.02  0.28
# 1  0.00  1.19  0.27 0.17  0.45  0.06 -0.08 -0.08  0.09 -0.26  ... -0.23 -0.64
# 2  1.00 -1.36 -1.34 1.77  0.38 -0.50  1.80  0.79  0.25 -1.51  ...  0.25  0.77
# 3  1.00 -0.97 -0.19 1.79 -0.86 -0.01  1.25  0.24  0.38 -1.39  ... -0.11  0.01
# 4  2.00 -1.16  0.88 1.55  0.40 -0.41  0.10  0.59 -0.27  0.82  ... -0.01  0.80
#
#     V23   V24   V25   V26   V27   V28  Amount  Class
# 0 -0.11  0.07  0.13 -0.19  0.13 -0.02  149.62      0
# 1  0.10 -0.34  0.17  0.13 -0.01  0.01    2.69      0
# 2  0.91 -0.69 -0.33 -0.14 -0.06 -0.06  378.66      0
# 3 -0.19 -1.18  0.65 -0.22  0.06  0.06  123.50      0
# 4 -0.14  0.14 -0.21  0.50  0.22  0.22   69.99      0
#
# [5 rows x 31 columns]

# %%
data = data.sample(n=25000, replace=True)

# %%
data.shape
# Out:
# (25000, 31)

# %% [markdown]
# ### Data Pre-Processing

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 175334 to 67337
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    25000 non-null  float64
#  1   V1      25000 non-null  float64
#  2   V2      25000 non-null  float64
#  3   V3      25000 non-null  float64
#  4   V4      25000 non-null  float64
#  5   V5      25000 non-null  float64
#  6   V6      25000 non-null  float64
#  7   V7      25000 non-null  float64
#  8   V8      25000 non-null  float64
#  9   V9      25000 non-null  float64
#  10  V10     25000 non-null  float64
#  11  V11     25000 non-null  float64
#  12  V12     25000 non-null  float64
#  13  V13     25000 non-null  float64
#  14  V14     25000 non-null  float64
#  15  V15     25000 non-null  float64
#  16  V16     25000 non-null  float64
#  17  V17     25000 non-null  float64
#  18  V18     25000 non-null  float64
#  19  V19     25000 non-null  float64
#  20  V20     25000 non-null  float64
#  21  V21     25000 non-null  float64
#  22  V22     25000 non-null  float64
#  23  V23     25000 non-null  float64
#  24  V24     25000 non-null  float64
#  25  V25     25000 non-null  float64
#  26  V26     25000 non-null  float64
#  27  V27     25000 non-null  float64
#  28  V28     25000 non-null  float64
#  29  Amount  25000 non-null  float64
#  30  Class   25000 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 6.1 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.drop('Time',axis=1,inplace=True)

# %%
data.describe().T
# Out:
#           count  mean    std    min   25%   50%   75%      max
# V1     25000.00 -0.01   1.96 -37.56 -0.92  0.01  1.31     2.41
# V2     25000.00 -0.01   1.72 -63.34 -0.60  0.07  0.81    12.79
# V3     25000.00 -0.01   1.49 -24.96 -0.90  0.17  1.03     3.94
# V4     25000.00 -0.01   1.41  -5.42 -0.85 -0.02  0.74    16.72
# V5     25000.00  0.00   1.39 -35.18 -0.70 -0.06  0.61    24.66
# V6     25000.00 -0.01   1.33 -17.57 -0.78 -0.28  0.39    21.55
# V7     25000.00 -0.00   1.21 -18.75 -0.56  0.04  0.57    36.88
# V8     25000.00 -0.00   1.18 -37.35 -0.21  0.02  0.32    11.16
# V9     25000.00  0.00   1.11  -8.09 -0.65 -0.06  0.60    10.33
# V10    25000.00  0.00   1.09 -14.68 -0.54 -0.10  0.47    15.24
# V11    25000.00 -0.01   1.02  -4.22 -0.76 -0.04  0.74     9.54
# V12    25000.00 -0.01   0.99 -17.00 -0.41  0.13  0.61     4.32
# V13    25000.00 -0.01   0.99  -3.79 -0.66 -0.03  0.66     4.32
# V14    25000.00 -0.01   0.96 -17.62 -0.43  0.04  0.49     6.24
# V15    25000.00  0.01   0.92  -3.92 -0.58  0.05  0.65     5.67
# V16    25000.00  0.01   0.87 -13.26 -0.47  0.07  0.53     8.29
# V17    25000.00  0.01   0.85 -21.68 -0.47 -0.05  0.41     5.67
# V18    25000.00 -0.00   0.84  -8.49 -0.50 -0.01  0.50     5.04
# V19    25000.00  0.00   0.82  -7.21 -0.46  0.01  0.46     5.59
# V20    25000.00  0.01   0.83 -28.01 -0.21 -0.06  0.14    39.42
# V21    25000.00  0.00   0.76 -14.03 -0.23 -0.03  0.19    27.20
# V22    25000.00 -0.00   0.73 -10.93 -0.54  0.00  0.53     5.89
# V23    25000.00  0.01   0.64 -22.58 -0.16 -0.01  0.15    15.88
# V24    25000.00  0.00   0.61  -2.84 -0.35  0.04  0.44     4.02
# V25    25000.00 -0.00   0.52  -7.03 -0.32  0.01  0.35     7.52
# V26    25000.00 -0.00   0.48  -2.53 -0.33 -0.06  0.23     3.16
# V27    25000.00  0.00   0.39  -6.92 -0.07  0.00  0.09     9.20
# V28    25000.00 -0.00   0.33  -8.46 -0.05  0.01  0.08    22.62
# Amount 25000.00 90.25 272.76   0.00  5.38 21.95 77.03 19656.53
# Class  25000.00  0.00   0.04   0.00  0.00  0.00  0.00     1.00

# %%
X = data.loc[:, data.columns != 'Class']     # All columns except target variable.
y = data['Class']                        # Target Variable.

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (17500, 29)
# (17500,)
# (7500, 29)
# (7500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [01:30<00:00,  3.10s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# GaussianNB                         0.98               0.95     0.95      0.99
# LGBMClassifier                     1.00               0.91     0.91      1.00
# XGBClassifier                      1.00               0.91     0.91      1.00
# ExtraTreeClassifier                1.00               0.91     0.91      1.00
# QuadraticDiscriminantAnalysis      0.99               0.91     0.91      1.00
# BernoulliNB                        1.00               0.86     0.86      1.00
# NearestCentroid                    1.00               0.86     0.86      1.00
# LinearDiscriminantAnalysis         1.00               0.86     0.86      1.00
# KNeighborsClassifier               1.00               0.86     0.86      1.00
# Perceptron                         1.00               0.86     0.86      1.00
# PassiveAggressiveClassifier        1.00               0.86     0.86      1.00
# DecisionTreeClassifier             1.00               0.86     0.86      1.00
# ExtraTreesClassifier               1.00               0.82     0.82      1.00
# RidgeClassifierCV                  1.00               0.82     0.82      1.00
# RidgeClassifier                    1.00               0.82     0.82      1.00
# SGDClassifier                      1.00               0.82     0.82      1.00
# RandomForestClassifier             1.00               0.82     0.82      1.00
# LogisticRegression                 1.00               0.82     0.82      1.00
# LinearSVC                          1.00               0.82     0.82      1.00
# AdaBoostClassifier                 1.00               0.77     0.77      1.00
# CalibratedClassifierCV             1.00               0.77     0.77      1.00
# BaggingClassifier                  1.00               0.73     0.73      1.00
# LabelSpreading                     1.00               0.64     0.64      1.00
# LabelPropagation                   1.00               0.64     0.64      1.00
# SVC                                1.00               0.64     0.64      1.00
# DummyClassifier                    1.00               0.50     0.50      1.00
#
#                                Time Taken
# Model
# GaussianNB                           0.08
# LGBMClassifier                       0.50
# XGBClassifier                        2.33
# ExtraTreeClassifier                  0.06
# QuadraticDiscriminantAnalysis        0.09
# BernoulliNB                          0.08
# NearestCentroid                      0.07
# LinearDiscriminantAnalysis           0.18
# KNeighborsClassifier                 0.86
# Perceptron                           0.08
# PassiveAggressiveClassifier          0.09
# DecisionTreeClassifier               0.45
# ExtraTreesClassifier                 1.02
# RidgeClassifierCV                    0.10
# RidgeClassifier                      0.07
# SGDClassifier                        0.10
# RandomForestClassifier               5.23
# LogisticRegression                   0.23
# LinearSVC                            1.80
# AdaBoostClassifier                   4.25
# CalibratedClassifierCV               4.58
# BaggingClassifier                    2.87
# LabelSpreading                      35.52
# LabelPropagation                    27.36
# SVC                                  1.86
# DummyClassifier                      0.05

# %% [markdown]
# ### Dimensionality Reduction Algorithms

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (17500, 5)
# (17500,)
# (7500, 5)
# (7500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:44<00:00,  1.54s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               0.86     0.86      1.00
# QuadraticDiscriminantAnalysis      0.99               0.86     0.86      0.99
# GaussianNB                         0.98               0.86     0.86      0.99
# LinearDiscriminantAnalysis         0.99               0.82     0.82      1.00
# NearestCentroid                    0.99               0.81     0.81      0.99
# ExtraTreesClassifier               1.00               0.77     0.77      1.00
# XGBClassifier                      1.00               0.77     0.77      1.00
# LabelPropagation                   1.00               0.77     0.77      1.00
# LabelSpreading                     1.00               0.77     0.77      1.00
# AdaBoostClassifier                 1.00               0.77     0.77      1.00
# KNeighborsClassifier               1.00               0.77     0.77      1.00
# ExtraTreeClassifier                1.00               0.77     0.77      1.00
# PassiveAggressiveClassifier        1.00               0.77     0.77      1.00
# RandomForestClassifier             1.00               0.73     0.73      1.00
# BaggingClassifier                  1.00               0.73     0.73      1.00
# LogisticRegression                 1.00               0.73     0.73      1.00
# SGDClassifier                      1.00               0.73     0.73      1.00
# DecisionTreeClassifier             1.00               0.73     0.73      1.00
# CalibratedClassifierCV             1.00               0.68     0.68      1.00
# LinearSVC                          1.00               0.68     0.68      1.00
# SVC                                1.00               0.68     0.68      1.00
# Perceptron                         1.00               0.68     0.68      1.00
# DummyClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifierCV                  1.00               0.50     0.50      1.00
# BernoulliNB                        1.00               0.50     0.50      1.00
#
#                                Time Taken
# Model
# LGBMClassifier                       0.25
# QuadraticDiscriminantAnalysis        0.02
# GaussianNB                           0.03
# LinearDiscriminantAnalysis           0.04
# NearestCentroid                      0.03
# ExtraTreesClassifier                 0.74
# XGBClassifier                        0.99
# LabelPropagation                    14.77
# LabelSpreading                      20.97
# AdaBoostClassifier                   1.50
# KNeighborsClassifier                 0.55
# ExtraTreeClassifier                  0.03
# PassiveAggressiveClassifier          0.04
# RandomForestClassifier               2.38
# BaggingClassifier                    0.58
# LogisticRegression                   0.05
# SGDClassifier                        0.04
# DecisionTreeClassifier               0.10
# CalibratedClassifierCV               0.58
# LinearSVC                            0.17
# SVC                                  0.67
# Perceptron                           0.03
# DummyClassifier                      0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.04
# BernoulliNB                          0.03

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (17500, 5)
# (17500,)
# (7500, 5)
# (7500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:44<00:00,  1.53s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               0.86     0.86      1.00
# QuadraticDiscriminantAnalysis      0.99               0.86     0.86      0.99
# GaussianNB                         0.98               0.86     0.86      0.99
# LinearDiscriminantAnalysis         0.99               0.82     0.82      1.00
# NearestCentroid                    0.99               0.81     0.81      0.99
# ExtraTreesClassifier               1.00               0.77     0.77      1.00
# XGBClassifier                      1.00               0.77     0.77      1.00
# LabelPropagation                   1.00               0.77     0.77      1.00
# LabelSpreading                     1.00               0.77     0.77      1.00
# AdaBoostClassifier                 1.00               0.77     0.77      1.00
# KNeighborsClassifier               1.00               0.77     0.77      1.00
# ExtraTreeClassifier                1.00               0.77     0.77      1.00
# PassiveAggressiveClassifier        1.00               0.77     0.77      1.00
# RandomForestClassifier             1.00               0.73     0.73      1.00
# BaggingClassifier                  1.00               0.73     0.73      1.00
# LogisticRegression                 1.00               0.73     0.73      1.00
# SGDClassifier                      1.00               0.73     0.73      1.00
# DecisionTreeClassifier             1.00               0.73     0.73      1.00
# CalibratedClassifierCV             1.00               0.68     0.68      1.00
# LinearSVC                          1.00               0.68     0.68      1.00
# SVC                                1.00               0.68     0.68      1.00
# Perceptron                         1.00               0.68     0.68      1.00
# DummyClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifierCV                  1.00               0.50     0.50      1.00
# BernoulliNB                        1.00               0.50     0.50      1.00
#
#                                Time Taken
# Model
# LGBMClassifier                       0.26
# QuadraticDiscriminantAnalysis        0.03
# GaussianNB                           0.02
# LinearDiscriminantAnalysis           0.04
# NearestCentroid                      0.02
# ExtraTreesClassifier                 0.74
# XGBClassifier                        1.02
# LabelPropagation                    15.10
# LabelSpreading                      20.89
# AdaBoostClassifier                   1.09
# KNeighborsClassifier                 0.58
# ExtraTreeClassifier                  0.03
# PassiveAggressiveClassifier          0.03
# RandomForestClassifier               2.34
# BaggingClassifier                    0.52
# LogisticRegression                   0.06
# SGDClassifier                        0.04
# DecisionTreeClassifier               0.11
# CalibratedClassifierCV               0.56
# LinearSVC                            0.16
# SVC                                  0.69
# Perceptron                           0.03
# DummyClassifier                      0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.04
# BernoulliNB                          0.03

# %% [markdown]
# ### Singular Decomposition Analysis

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (17500, 5)
# (17500,)
# (7500, 5)
# (7500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:44<00:00,  1.52s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               0.86     0.86      1.00
# QuadraticDiscriminantAnalysis      0.99               0.86     0.86      0.99
# GaussianNB                         0.98               0.86     0.86      0.99
# LinearDiscriminantAnalysis         0.99               0.82     0.82      1.00
# NearestCentroid                    0.99               0.81     0.81      0.99
# ExtraTreesClassifier               1.00               0.77     0.77      1.00
# XGBClassifier                      1.00               0.77     0.77      1.00
# LabelPropagation                   1.00               0.77     0.77      1.00
# LabelSpreading                     1.00               0.77     0.77      1.00
# AdaBoostClassifier                 1.00               0.77     0.77      1.00
# KNeighborsClassifier               1.00               0.77     0.77      1.00
# ExtraTreeClassifier                1.00               0.77     0.77      1.00
# PassiveAggressiveClassifier        1.00               0.77     0.77      1.00
# RandomForestClassifier             1.00               0.73     0.73      1.00
# BaggingClassifier                  1.00               0.73     0.73      1.00
# LogisticRegression                 1.00               0.73     0.73      1.00
# SGDClassifier                      1.00               0.73     0.73      1.00
# DecisionTreeClassifier             1.00               0.73     0.73      1.00
# CalibratedClassifierCV             1.00               0.68     0.68      1.00
# LinearSVC                          1.00               0.68     0.68      1.00
# SVC                                1.00               0.68     0.68      1.00
# Perceptron                         1.00               0.68     0.68      1.00
# DummyClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifierCV                  1.00               0.50     0.50      1.00
# BernoulliNB                        1.00               0.50     0.50      1.00
#
#                                Time Taken
# Model
# LGBMClassifier                       0.31
# QuadraticDiscriminantAnalysis        0.03
# GaussianNB                           0.02
# LinearDiscriminantAnalysis           0.04
# NearestCentroid                      0.02
# ExtraTreesClassifier                 0.71
# XGBClassifier                        1.02
# LabelPropagation                    15.08
# LabelSpreading                      20.66
# AdaBoostClassifier                   1.14
# KNeighborsClassifier                 0.56
# ExtraTreeClassifier                  0.03
# PassiveAggressiveClassifier          0.03
# RandomForestClassifier               2.31
# BaggingClassifier                    0.44
# LogisticRegression                   0.05
# SGDClassifier                        0.04
# DecisionTreeClassifier               0.10
# CalibratedClassifierCV               0.59
# LinearSVC                            0.16
# SVC                                  0.68
# Perceptron                           0.03
# DummyClassifier                      0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.04
# BernoulliNB                          0.03

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (17500, 5)
# (17500,)
# (7500, 5)
# (7500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:47<00:00,  1.64s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               0.86     0.86      1.00
# QuadraticDiscriminantAnalysis      0.99               0.86     0.86      0.99
# GaussianNB                         0.98               0.86     0.86      0.99
# LinearDiscriminantAnalysis         0.99               0.82     0.82      1.00
# NearestCentroid                    0.99               0.81     0.81      0.99
# ExtraTreesClassifier               1.00               0.77     0.77      1.00
# XGBClassifier                      1.00               0.77     0.77      1.00
# LabelPropagation                   1.00               0.77     0.77      1.00
# LabelSpreading                     1.00               0.77     0.77      1.00
# AdaBoostClassifier                 1.00               0.77     0.77      1.00
# KNeighborsClassifier               1.00               0.77     0.77      1.00
# ExtraTreeClassifier                1.00               0.77     0.77      1.00
# PassiveAggressiveClassifier        1.00               0.77     0.77      1.00
# RandomForestClassifier             1.00               0.73     0.73      1.00
# BaggingClassifier                  1.00               0.73     0.73      1.00
# LogisticRegression                 1.00               0.73     0.73      1.00
# SGDClassifier                      1.00               0.73     0.73      1.00
# DecisionTreeClassifier             1.00               0.73     0.73      1.00
# CalibratedClassifierCV             1.00               0.68     0.68      1.00
# LinearSVC                          1.00               0.68     0.68      1.00
# SVC                                1.00               0.68     0.68      1.00
# Perceptron                         1.00               0.68     0.68      1.00
# DummyClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifier                    1.00               0.50     0.50      1.00
# RidgeClassifierCV                  1.00               0.50     0.50      1.00
# BernoulliNB                        1.00               0.50     0.50      1.00
#
#                                Time Taken
# Model
# LGBMClassifier                       0.26
# QuadraticDiscriminantAnalysis        0.04
# GaussianNB                           0.02
# LinearDiscriminantAnalysis           0.07
# NearestCentroid                      0.04
# ExtraTreesClassifier                 0.73
# XGBClassifier                        1.20
# LabelPropagation                    14.06
# LabelSpreading                      22.76
# AdaBoostClassifier                   1.24
# KNeighborsClassifier                 0.56
# ExtraTreeClassifier                  0.03
# PassiveAggressiveClassifier          0.06
# RandomForestClassifier               3.60
# BaggingClassifier                    0.48
# LogisticRegression                   0.08
# SGDClassifier                        0.06
# DecisionTreeClassifier               0.10
# CalibratedClassifierCV               0.55
# LinearSVC                            0.27
# SVC                                  1.00
# Perceptron                           0.05
# DummyClassifier                      0.03
# RidgeClassifier                      0.05
# RidgeClassifierCV                    0.05
# BernoulliNB                          0.03

# %% [markdown]
# ## Dataset 6 : Customer Churn Dataset

# %% [markdown]
# Dataset we are using in this case study contain 5000 customer records and 21 features. We are  using “class” as our target variable. It is a Binary class classification problem where value of class
# is 0 and 1 (0 means do not churn and 1 means churn). Data set contain other features as well such
# as state, phone number et

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:/Churn_data_set.csv")
data.shape
# Out:
# (5000, 21)

# %%
data.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25             265.10              110
# 1                1                     26             161.60              123
# 2                0                      0             243.40              114
# 3                0                      0             299.40               71
# 4                0                      0             166.70              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0               244.70                 91               11.01
# 1               254.40                103               11.45
# 2               162.60                104                7.32
# 3               196.90                 89                8.86
# 4               186.90                121                8.41
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0               10.00                 3               2.70
# 1               13.70                 3               3.70
# 2               12.20                 5               3.29
# 3                6.60                 7               1.78
# 4               10.10                 3               2.73
#
#    number_customer_service_calls  class
# 0                              1      0
# 1                              1      0
# 2                              0      0
# 3                              2      0
# 4                              3      0
#
# [5 rows x 21 columns]

# %%
data.isna().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# class                            0
# dtype: int64

# %%
X = data.loc[:, data.columns != 'class']     # All columns except target variable.
y = data['class']                        # Target Variable.

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (3500, 20)
# (3500,)
# (1500, 20)
# (1500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:08<00:00,  3.23it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.95               0.86     0.86      0.95
# RandomForestClassifier             0.95               0.85     0.85      0.95
# DecisionTreeClassifier             0.91               0.83     0.83      0.91
# ExtraTreesClassifier               0.93               0.77     0.77      0.92
# QuadraticDiscriminantAnalysis      0.88               0.75     0.75      0.88
# SVC                                0.92               0.75     0.75      0.91
# NearestCentroid                    0.74               0.74     0.74      0.77
# GaussianNB                         0.87               0.74     0.74      0.87
# Perceptron                         0.83               0.69     0.69      0.83
# ExtraTreeClassifier                0.84               0.68     0.68      0.84
# LabelPropagation                   0.85               0.66     0.66      0.84
# LabelSpreading                     0.85               0.66     0.66      0.84
# KNeighborsClassifier               0.89               0.65     0.65      0.87
# AdaBoostClassifier                 0.88               0.65     0.65      0.86
# LinearDiscriminantAnalysis         0.86               0.62     0.62      0.84
# LogisticRegression                 0.86               0.60     0.60      0.83
# CalibratedClassifierCV             0.86               0.59     0.59      0.83
# PassiveAggressiveClassifier        0.84               0.57     0.57      0.81
# LinearSVC                          0.86               0.57     0.57      0.82
# SGDClassifier                      0.85               0.56     0.56      0.81
# BernoulliNB                        0.85               0.55     0.55      0.81
# RidgeClassifier                    0.86               0.54     0.54      0.81
# RidgeClassifierCV                  0.86               0.54     0.54      0.81
# DummyClassifier                    0.85               0.50     0.50      0.78
#
#                                Time Taken
# Model
# XGBClassifier                        0.52
# LGBMClassifier                       0.25
# BaggingClassifier                    0.44
# RandomForestClassifier               0.90
# DecisionTreeClassifier               0.07
# ExtraTreesClassifier                 0.63
# QuadraticDiscriminantAnalysis        0.03
# SVC                                  0.53
# NearestCentroid                      0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# ExtraTreeClassifier                  0.02
# LabelPropagation                     1.34
# LabelSpreading                       1.52
# KNeighborsClassifier                 0.18
# AdaBoostClassifier                   0.66
# LinearDiscriminantAnalysis           0.03
# LogisticRegression                   0.03
# CalibratedClassifierCV               1.27
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.27
# SGDClassifier                        0.04
# BernoulliNB                          0.03
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.02

# %% [markdown]
# ### Dimensionality Reduction Algorithm

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (3500, 20)
# (3500,)
# (1500, 20)
# (1500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:09<00:00,  3.21it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.95               0.86     0.86      0.95
# RandomForestClassifier             0.95               0.85     0.85      0.95
# DecisionTreeClassifier             0.91               0.83     0.83      0.91
# ExtraTreesClassifier               0.93               0.77     0.77      0.92
# QuadraticDiscriminantAnalysis      0.88               0.75     0.75      0.88
# SVC                                0.92               0.75     0.75      0.91
# NearestCentroid                    0.74               0.74     0.74      0.77
# GaussianNB                         0.87               0.74     0.74      0.87
# Perceptron                         0.83               0.69     0.69      0.83
# ExtraTreeClassifier                0.84               0.68     0.68      0.84
# LabelPropagation                   0.85               0.66     0.66      0.84
# LabelSpreading                     0.85               0.66     0.66      0.84
# KNeighborsClassifier               0.89               0.65     0.65      0.87
# AdaBoostClassifier                 0.88               0.65     0.65      0.86
# LinearDiscriminantAnalysis         0.86               0.62     0.62      0.84
# LogisticRegression                 0.86               0.60     0.60      0.83
# CalibratedClassifierCV             0.86               0.59     0.59      0.83
# PassiveAggressiveClassifier        0.84               0.57     0.57      0.81
# LinearSVC                          0.86               0.57     0.57      0.82
# SGDClassifier                      0.85               0.56     0.56      0.81
# BernoulliNB                        0.85               0.55     0.55      0.81
# RidgeClassifier                    0.86               0.54     0.54      0.81
# RidgeClassifierCV                  0.86               0.54     0.54      0.81
# DummyClassifier                    0.85               0.50     0.50      0.78
#
#                                Time Taken
# Model
# XGBClassifier                        0.85
# LGBMClassifier                       0.50
# BaggingClassifier                    0.37
# RandomForestClassifier               1.00
# DecisionTreeClassifier               0.06
# ExtraTreesClassifier                 0.56
# QuadraticDiscriminantAnalysis        0.03
# SVC                                  0.66
# NearestCentroid                      0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# ExtraTreeClassifier                  0.02
# LabelPropagation                     1.19
# LabelSpreading                       1.49
# KNeighborsClassifier                 0.17
# AdaBoostClassifier                   0.51
# LinearDiscriminantAnalysis           0.03
# LogisticRegression                   0.03
# CalibratedClassifierCV               1.05
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.27
# SGDClassifier                        0.05
# BernoulliNB                          0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.04
# DummyClassifier                      0.02

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (3500, 20)
# (3500,)
# (1500, 20)
# (1500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:09<00:00,  3.10it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.95               0.86     0.86      0.95
# RandomForestClassifier             0.95               0.85     0.85      0.95
# DecisionTreeClassifier             0.91               0.83     0.83      0.91
# ExtraTreesClassifier               0.93               0.77     0.77      0.92
# QuadraticDiscriminantAnalysis      0.88               0.75     0.75      0.88
# SVC                                0.92               0.75     0.75      0.91
# NearestCentroid                    0.74               0.74     0.74      0.77
# GaussianNB                         0.87               0.74     0.74      0.87
# Perceptron                         0.83               0.69     0.69      0.83
# ExtraTreeClassifier                0.84               0.68     0.68      0.84
# LabelPropagation                   0.85               0.66     0.66      0.84
# LabelSpreading                     0.85               0.66     0.66      0.84
# KNeighborsClassifier               0.89               0.65     0.65      0.87
# AdaBoostClassifier                 0.88               0.65     0.65      0.86
# LinearDiscriminantAnalysis         0.86               0.62     0.62      0.84
# LogisticRegression                 0.86               0.60     0.60      0.83
# CalibratedClassifierCV             0.86               0.59     0.59      0.83
# PassiveAggressiveClassifier        0.84               0.57     0.57      0.81
# LinearSVC                          0.86               0.57     0.57      0.82
# SGDClassifier                      0.85               0.56     0.56      0.81
# BernoulliNB                        0.85               0.55     0.55      0.81
# RidgeClassifier                    0.86               0.54     0.54      0.81
# RidgeClassifierCV                  0.86               0.54     0.54      0.81
# DummyClassifier                    0.85               0.50     0.50      0.78
#
#                                Time Taken
# Model
# XGBClassifier                        1.04
# LGBMClassifier                       0.80
# BaggingClassifier                    0.38
# RandomForestClassifier               0.93
# DecisionTreeClassifier               0.08
# ExtraTreesClassifier                 0.50
# QuadraticDiscriminantAnalysis        0.03
# SVC                                  0.66
# NearestCentroid                      0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# ExtraTreeClassifier                  0.03
# LabelPropagation                     1.17
# LabelSpreading                       1.49
# KNeighborsClassifier                 0.16
# AdaBoostClassifier                   0.44
# LinearDiscriminantAnalysis           0.04
# LogisticRegression                   0.04
# CalibratedClassifierCV               1.04
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.27
# SGDClassifier                        0.06
# BernoulliNB                          0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.03

# %% [markdown]
# ### Singular Vector Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (3500, 20)
# (3500,)
# (1500, 20)
# (1500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:08<00:00,  3.60it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.95               0.86     0.86      0.95
# RandomForestClassifier             0.95               0.85     0.85      0.95
# DecisionTreeClassifier             0.91               0.83     0.83      0.91
# ExtraTreesClassifier               0.93               0.77     0.77      0.92
# QuadraticDiscriminantAnalysis      0.88               0.75     0.75      0.88
# SVC                                0.92               0.75     0.75      0.91
# NearestCentroid                    0.74               0.74     0.74      0.77
# GaussianNB                         0.87               0.74     0.74      0.87
# Perceptron                         0.83               0.69     0.69      0.83
# ExtraTreeClassifier                0.84               0.68     0.68      0.84
# LabelPropagation                   0.85               0.66     0.66      0.84
# LabelSpreading                     0.85               0.66     0.66      0.84
# KNeighborsClassifier               0.89               0.65     0.65      0.87
# AdaBoostClassifier                 0.88               0.65     0.65      0.86
# LinearDiscriminantAnalysis         0.86               0.62     0.62      0.84
# LogisticRegression                 0.86               0.60     0.60      0.83
# CalibratedClassifierCV             0.86               0.59     0.59      0.83
# PassiveAggressiveClassifier        0.84               0.57     0.57      0.81
# LinearSVC                          0.86               0.57     0.57      0.82
# SGDClassifier                      0.85               0.56     0.56      0.81
# BernoulliNB                        0.85               0.55     0.55      0.81
# RidgeClassifier                    0.86               0.54     0.54      0.81
# RidgeClassifierCV                  0.86               0.54     0.54      0.81
# DummyClassifier                    0.85               0.50     0.50      0.78
#
#                                Time Taken
# Model
# XGBClassifier                        0.53
# LGBMClassifier                       0.24
# BaggingClassifier                    0.39
# RandomForestClassifier               0.90
# DecisionTreeClassifier               0.07
# ExtraTreesClassifier                 0.60
# QuadraticDiscriminantAnalysis        0.03
# SVC                                  0.54
# NearestCentroid                      0.02
# GaussianNB                           0.03
# Perceptron                           0.02
# ExtraTreeClassifier                  0.03
# LabelPropagation                     1.10
# LabelSpreading                       1.38
# KNeighborsClassifier                 0.15
# AdaBoostClassifier                   0.45
# LinearDiscriminantAnalysis           0.03
# LogisticRegression                   0.04
# CalibratedClassifierCV               1.08
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.26
# SGDClassifier                        0.03
# BernoulliNB                          0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.02

# %% [markdown]
# ### TSNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (3500, 20)
# (3500,)
# (1500, 20)
# (1500,)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:08<00:00,  3.60it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.96               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.95               0.86     0.86      0.95
# RandomForestClassifier             0.95               0.85     0.85      0.95
# DecisionTreeClassifier             0.91               0.83     0.83      0.91
# ExtraTreesClassifier               0.93               0.77     0.77      0.92
# QuadraticDiscriminantAnalysis      0.88               0.75     0.75      0.88
# SVC                                0.92               0.75     0.75      0.91
# NearestCentroid                    0.74               0.74     0.74      0.77
# GaussianNB                         0.87               0.74     0.74      0.87
# Perceptron                         0.83               0.69     0.69      0.83
# ExtraTreeClassifier                0.84               0.68     0.68      0.84
# LabelPropagation                   0.85               0.66     0.66      0.84
# LabelSpreading                     0.85               0.66     0.66      0.84
# KNeighborsClassifier               0.89               0.65     0.65      0.87
# AdaBoostClassifier                 0.88               0.65     0.65      0.86
# LinearDiscriminantAnalysis         0.86               0.62     0.62      0.84
# LogisticRegression                 0.86               0.60     0.60      0.83
# CalibratedClassifierCV             0.86               0.59     0.59      0.83
# PassiveAggressiveClassifier        0.84               0.57     0.57      0.81
# LinearSVC                          0.86               0.57     0.57      0.82
# SGDClassifier                      0.85               0.56     0.56      0.81
# BernoulliNB                        0.85               0.55     0.55      0.81
# RidgeClassifier                    0.86               0.54     0.54      0.81
# RidgeClassifierCV                  0.86               0.54     0.54      0.81
# DummyClassifier                    0.85               0.50     0.50      0.78
#
#                                Time Taken
# Model
# XGBClassifier                        0.49
# LGBMClassifier                       0.24
# BaggingClassifier                    0.38
# RandomForestClassifier               0.88
# DecisionTreeClassifier               0.08
# ExtraTreesClassifier                 0.51
# QuadraticDiscriminantAnalysis        0.02
# SVC                                  0.53
# NearestCentroid                      0.02
# GaussianNB                           0.02
# Perceptron                           0.02
# ExtraTreeClassifier                  0.02
# LabelPropagation                     1.17
# LabelSpreading                       1.35
# KNeighborsClassifier                 0.16
# AdaBoostClassifier                   0.51
# LinearDiscriminantAnalysis           0.04
# LogisticRegression                   0.03
# CalibratedClassifierCV               1.14
# PassiveAggressiveClassifier          0.02
# LinearSVC                            0.26
# SGDClassifier                        0.04
# BernoulliNB                          0.03
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.02

# %% [markdown]
# ## Dataset 7 : Brest Cancer Wisconsin Dataset

# %% [markdown]
# Data Info : This datset is take from UCI Machine learning repository. Its a binary class classififcation dataset.
#
# Link for data : https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(diagnostic)

# %%
# Importing Dataset using Pandas.
data = pd.read_csv("E:\DOWNLOADS\Brest_Cancer_data.csv.csv")
data.shape
# Out:
# (569, 33)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
# Checking Null values in all features.
data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
# Dropping unimpactful colums
data.drop('Unnamed: 32',axis=1,inplace=True)
data.drop('id',axis=1,inplace=True)

# %%
data.dtypes
# Out:
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
data['diagnosis'] = data['diagnosis'].map({'B': 0, 'M': 1})
data['diagnosis'] = pd.to_numeric(data['diagnosis'])

# %%
X = data.loc[:, data.columns != 'diagnosis']
y = data[['diagnosis']]

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
X_scaled.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                2.255747  ...      1.886690      -1.359293         2.303601
# 1               -0.868652  ...      1.805927      -0.369203         1.535126
# 2               -0.398008  ...      1.511870      -0.023974         1.347475
# 3                4.910919  ...     -0.281464       0.133984        -0.249939
# 4               -0.562450  ...      1.298575      -1.466770         1.338539
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    2.001237          1.307686           2.616665         2.109526
# 1    1.890489         -0.375612          -0.430444        -0.146749
# 2    1.456285          0.527407           1.082932         0.854974
# 3   -0.550021          3.394275           3.893397         1.989588
# 4    1.220724          0.220556          -0.313395         0.613179
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.750622                 1.937015
# 1              1.087084       -0.243890                 0.281190
# 2              1.955000        1.152255                 0.201391
# 3              2.175786        6.046041                 4.935010
# 4              0.729259       -0.868353                -0.397100
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (398, 30)
# (398, 1)
# (171, 30)
# (171, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 12.69it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# SVC                                0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.98     0.98      0.98
# PassiveAggressiveClassifier        0.97               0.97     0.97      0.97
# LGBMClassifier                     0.97               0.97     0.97      0.97
# LogisticRegression                 0.97               0.97     0.97      0.97
# SGDClassifier                      0.96               0.97     0.97      0.97
# BaggingClassifier                  0.96               0.97     0.97      0.96
# XGBClassifier                      0.96               0.97     0.97      0.96
# ExtraTreesClassifier               0.96               0.96     0.96      0.96
# CalibratedClassifierCV             0.97               0.96     0.96      0.97
# QuadraticDiscriminantAnalysis      0.96               0.96     0.96      0.96
# Perceptron                         0.95               0.96     0.96      0.95
# RandomForestClassifier             0.95               0.95     0.95      0.95
# AdaBoostClassifier                 0.95               0.95     0.95      0.95
# LinearSVC                          0.95               0.95     0.95      0.95
# LinearDiscriminantAnalysis         0.95               0.94     0.94      0.95
# RidgeClassifier                    0.95               0.94     0.94      0.95
# RidgeClassifierCV                  0.95               0.94     0.94      0.95
# GaussianNB                         0.94               0.94     0.94      0.94
# NuSVC                              0.95               0.94     0.94      0.95
# NearestCentroid                    0.94               0.93     0.93      0.94
# BernoulliNB                        0.92               0.92     0.92      0.92
# DecisionTreeClassifier             0.92               0.92     0.92      0.92
# LabelSpreading                     0.92               0.91     0.91      0.92
# LabelPropagation                   0.92               0.91     0.91      0.92
# ExtraTreeClassifier                0.91               0.90     0.90      0.91
# DummyClassifier                    0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# SVC                                  0.02
# KNeighborsClassifier                 0.22
# PassiveAggressiveClassifier          0.02
# LGBMClassifier                       0.16
# LogisticRegression                   0.03
# SGDClassifier                        0.02
# BaggingClassifier                    0.08
# XGBClassifier                        0.48
# ExtraTreesClassifier                 0.25
# CalibratedClassifierCV               0.08
# QuadraticDiscriminantAnalysis        0.03
# Perceptron                           0.02
# RandomForestClassifier               0.30
# AdaBoostClassifier                   0.21
# LinearSVC                            0.03
# LinearDiscriminantAnalysis           0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# GaussianNB                           0.03
# NuSVC                                0.04
# NearestCentroid                      0.01
# BernoulliNB                          0.02
# DecisionTreeClassifier               0.02
# LabelSpreading                       0.05
# LabelPropagation                     0.04
# ExtraTreeClassifier                  0.03
# DummyClassifier                      0.02

# %% [markdown]
# ### Dimensionality Reduction Algorithm

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (398, 5)
# (398, 1)
# (171, 5)
# (171, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 18.98it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.98               0.97     0.97      0.98
# SGDClassifier                      0.97               0.97     0.97      0.97
# LinearSVC                          0.96               0.96     0.96      0.96
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# CalibratedClassifierCV             0.96               0.96     0.96      0.96
# RandomForestClassifier             0.96               0.96     0.96      0.96
# ExtraTreesClassifier               0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# Perceptron                         0.96               0.96     0.96      0.96
# LogisticRegression                 0.96               0.96     0.96      0.96
# KNeighborsClassifier               0.96               0.96     0.96      0.96
# LinearDiscriminantAnalysis         0.96               0.96     0.96      0.96
# SVC                                0.95               0.95     0.95      0.95
# QuadraticDiscriminantAnalysis      0.95               0.95     0.95      0.95
# LGBMClassifier                     0.95               0.95     0.95      0.95
# BaggingClassifier                  0.95               0.95     0.95      0.95
# XGBClassifier                      0.95               0.95     0.95      0.95
# RidgeClassifier                    0.96               0.95     0.95      0.96
# RidgeClassifierCV                  0.96               0.95     0.95      0.96
# GaussianNB                         0.95               0.95     0.95      0.95
# AdaBoostClassifier                 0.94               0.94     0.94      0.94
# NuSVC                              0.95               0.93     0.93      0.95
# DecisionTreeClassifier             0.93               0.93     0.93      0.93
# BernoulliNB                        0.93               0.93     0.93      0.93
# ExtraTreeClassifier                0.89               0.88     0.88      0.89
# DummyClassifier                    0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# SGDClassifier                        0.02
# LinearSVC                            0.02
# PassiveAggressiveClassifier          0.02
# CalibratedClassifierCV               0.06
# RandomForestClassifier               0.31
# ExtraTreesClassifier                 0.20
# LabelPropagation                     0.03
# LabelSpreading                       0.03
# Perceptron                           0.02
# LogisticRegression                   0.02
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.02
# SVC                                  0.02
# QuadraticDiscriminantAnalysis        0.02
# LGBMClassifier                       0.10
# BaggingClassifier                    0.06
# XGBClassifier                        0.08
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# GaussianNB                           0.02
# AdaBoostClassifier                   0.27
# NuSVC                                0.03
# DecisionTreeClassifier               0.02
# BernoulliNB                          0.02
# ExtraTreeClassifier                  0.02
# DummyClassifier                      0.01

# %% [markdown]
# ### Linear Decomposition Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (398, 1)
# (398, 1)
# (171, 1)
# (171, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 18.95it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.98               0.98     0.98      0.98
# LabelPropagation                   0.98               0.98     0.98      0.98
# SGDClassifier                      0.98               0.98     0.98      0.98
# LabelSpreading                     0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.98     0.98      0.98
# BernoulliNB                        0.98               0.98     0.98      0.98
# Perceptron                         0.98               0.98     0.98      0.98
# XGBClassifier                      0.98               0.97     0.97      0.98
# RandomForestClassifier             0.98               0.97     0.97      0.98
# BaggingClassifier                  0.98               0.97     0.97      0.98
# AdaBoostClassifier                 0.98               0.97     0.97      0.98
# ExtraTreesClassifier               0.98               0.97     0.97      0.98
# DecisionTreeClassifier             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.98               0.97     0.97      0.98
# GaussianNB                         0.98               0.97     0.97      0.98
# LogisticRegression                 0.98               0.97     0.97      0.98
# NearestCentroid                    0.98               0.97     0.97      0.98
# PassiveAggressiveClassifier        0.98               0.97     0.97      0.98
# QuadraticDiscriminantAnalysis      0.98               0.97     0.97      0.98
# SVC                                0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# ExtraTreeClassifier                0.97               0.97     0.97      0.97
# LinearDiscriminantAnalysis         0.97               0.96     0.96      0.97
# NuSVC                              0.97               0.96     0.96      0.97
# RidgeClassifier                    0.97               0.96     0.96      0.97
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# DummyClassifier                    0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# LinearSVC                            0.03
# LabelPropagation                     0.03
# SGDClassifier                        0.01
# LabelSpreading                       0.03
# KNeighborsClassifier                 0.04
# BernoulliNB                          0.01
# Perceptron                           0.02
# XGBClassifier                        0.08
# RandomForestClassifier               0.30
# BaggingClassifier                    0.06
# AdaBoostClassifier                   0.25
# ExtraTreesClassifier                 0.23
# DecisionTreeClassifier               0.02
# LGBMClassifier                       0.09
# GaussianNB                           0.02
# LogisticRegression                   0.02
# NearestCentroid                      0.01
# PassiveAggressiveClassifier          0.02
# QuadraticDiscriminantAnalysis        0.02
# SVC                                  0.02
# CalibratedClassifierCV               0.05
# ExtraTreeClassifier                  0.02
# LinearDiscriminantAnalysis           0.02
# NuSVC                                0.03
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# DummyClassifier                      0.03

# %% [markdown]
# ### Singular Vector Decomposition

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (398, 5)
# (398, 1)
# (171, 5)
# (171, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 21.47it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.98               0.97     0.97      0.98
# SGDClassifier                      0.97               0.97     0.97      0.97
# LinearSVC                          0.96               0.96     0.96      0.96
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# CalibratedClassifierCV             0.96               0.96     0.96      0.96
# RandomForestClassifier             0.96               0.96     0.96      0.96
# ExtraTreesClassifier               0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# Perceptron                         0.96               0.96     0.96      0.96
# LogisticRegression                 0.96               0.96     0.96      0.96
# KNeighborsClassifier               0.96               0.96     0.96      0.96
# LinearDiscriminantAnalysis         0.96               0.96     0.96      0.96
# SVC                                0.95               0.95     0.95      0.95
# QuadraticDiscriminantAnalysis      0.95               0.95     0.95      0.95
# LGBMClassifier                     0.95               0.95     0.95      0.95
# BaggingClassifier                  0.95               0.95     0.95      0.95
# XGBClassifier                      0.95               0.95     0.95      0.95
# RidgeClassifier                    0.96               0.95     0.95      0.96
# RidgeClassifierCV                  0.96               0.95     0.95      0.96
# GaussianNB                         0.95               0.95     0.95      0.95
# AdaBoostClassifier                 0.94               0.94     0.94      0.94
# NuSVC                              0.95               0.93     0.93      0.95
# DecisionTreeClassifier             0.93               0.93     0.93      0.93
# BernoulliNB                        0.93               0.93     0.93      0.93
# ExtraTreeClassifier                0.89               0.88     0.88      0.89
# DummyClassifier                    0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# NearestCentroid                      0.02
# SGDClassifier                        0.02
# LinearSVC                            0.02
# PassiveAggressiveClassifier          0.01
# CalibratedClassifierCV               0.06
# RandomForestClassifier               0.26
# ExtraTreesClassifier                 0.18
# LabelPropagation                     0.02
# LabelSpreading                       0.03
# Perceptron                           0.02
# LogisticRegression                   0.02
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.02
# SVC                                  0.03
# QuadraticDiscriminantAnalysis        0.02
# LGBMClassifier                       0.10
# BaggingClassifier                    0.05
# XGBClassifier                        0.09
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# GaussianNB                           0.02
# AdaBoostClassifier                   0.21
# NuSVC                                0.03
# DecisionTreeClassifier               0.03
# BernoulliNB                          0.01
# ExtraTreeClassifier                  0.02
# DummyClassifier                      0.02

# %% [markdown]
# ### T-SNE

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_reduced, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (398, 2)
# (398, 1)
# (171, 2)
# (171, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 23.41it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.96               0.96     0.96      0.96
# KNeighborsClassifier               0.96               0.96     0.96      0.96
# RandomForestClassifier             0.96               0.95     0.95      0.96
# SVC                                0.96               0.95     0.95      0.96
# XGBClassifier                      0.95               0.95     0.95      0.95
# LabelSpreading                     0.95               0.95     0.95      0.95
# BaggingClassifier                  0.95               0.95     0.95      0.95
# LabelPropagation                   0.95               0.95     0.95      0.95
# LinearSVC                          0.96               0.95     0.95      0.96
# CalibratedClassifierCV             0.96               0.95     0.95      0.96
# LogisticRegression                 0.96               0.95     0.95      0.96
# AdaBoostClassifier                 0.95               0.95     0.95      0.95
# BernoulliNB                        0.95               0.95     0.95      0.95
# DecisionTreeClassifier             0.94               0.94     0.94      0.94
# LinearDiscriminantAnalysis         0.95               0.94     0.94      0.95
# GaussianNB                         0.95               0.94     0.94      0.95
# PassiveAggressiveClassifier        0.95               0.94     0.94      0.95
# Perceptron                         0.95               0.94     0.94      0.95
# RidgeClassifier                    0.95               0.94     0.94      0.95
# RidgeClassifierCV                  0.95               0.94     0.94      0.95
# SGDClassifier                      0.95               0.94     0.94      0.95
# LGBMClassifier                     0.94               0.94     0.94      0.94
# NearestCentroid                    0.95               0.94     0.94      0.95
# QuadraticDiscriminantAnalysis      0.95               0.94     0.94      0.95
# NuSVC                              0.95               0.93     0.93      0.95
# ExtraTreeClassifier                0.93               0.92     0.92      0.93
# DummyClassifier                    0.61               0.50     0.50      0.46
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.16
# KNeighborsClassifier                 0.03
# RandomForestClassifier               0.20
# SVC                                  0.03
# XGBClassifier                        0.13
# LabelSpreading                       0.03
# BaggingClassifier                    0.04
# LabelPropagation                     0.03
# LinearSVC                            0.01
# CalibratedClassifierCV               0.05
# LogisticRegression                   0.02
# AdaBoostClassifier                   0.16
# BernoulliNB                          0.02
# DecisionTreeClassifier               0.02
# LinearDiscriminantAnalysis           0.01
# GaussianNB                           0.01
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.02
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.02
# SGDClassifier                        0.02
# LGBMClassifier                       0.11
# NearestCentroid                      0.02
# QuadraticDiscriminantAnalysis        0.01
# NuSVC                                0.03
# ExtraTreeClassifier                  0.01
# DummyClassifier                      0.01

# %% [markdown]
# ## Dataset 8: Accident Severity Prediction

# %% [markdown]
# Dataset we are using in this project is basically taken from famous dataset. Name of dataset is 1.6 million UK Accidents, this is a countrywide car accident dataset, which covers both urban and rural areas of the UK. Each accident record is described by a wide range of data attributes, including the accident location, weather, time, Date etc. This dataset is officially collected by UK Police department and contain mostly severe accidents in which police was also involved. Dataset is officially present on Government of UK website. Whole datasets consist of three CSV files, each CSV file has around 4 lac and 70 thousand records and 33 different features. All 3 CSV files contain same columns and same number of records. First CSV consist of  record of 2005 to 2007, whereas second CSV contain records of accidents happened in time of 2009 to 2011 and third contain data of year 2012 to 2014. Raw data need to be pre-processed, including removing variables with too many missing values, filling variables, dropping unique features, and encoding variables.

# %%
data = pd.read_csv("E:/accidents_2012_to_2014.csv")
data.shape
# Out:
# (464697, 33)

# %%
data = data.sample(n=30000, replace=True)

# %%
data.shape
# Out:
# (30000, 33)

# %%
data.isnull().sum()
# Out:
# Accident_Index                                     0
# Location_Easting_OSGR                              0
# Location_Northing_OSGR                             0
# Longitude                                          0
# Latitude                                           0
# Police_Force                                       0
# Accident_Severity                                  0
# Number_of_Vehicles                                 0
# Number_of_Casualties                               0
# Date                                               0
# Day_of_Week                                        0
# Time                                               0
# Local_Authority_(District)                         0
# Local_Authority_(Highway)                          0
# 1st_Road_Class                                     0
# 1st_Road_Number                                    0
# Road_Type                                          0
# Speed_limit                                        0
# Junction_Detail                                30000
# Junction_Control                               11598
# 2nd_Road_Class                                     0
# 2nd_Road_Number                                    0
# Pedestrian_Crossing-Human_Control                  0
# Pedestrian_Crossing-Physical_Facilities            0
# Light_Conditions                                   0
# Weather_Conditions                                 0
# Road_Surface_Conditions                           49
# Special_Conditions_at_Site                         0
# Carriageway_Hazards                                0
# Urban_or_Rural_Area                                0
# Did_Police_Officer_Attend_Scene_of_Accident        1
# LSOA_of_Accident_Location                       1855
# Year                                               0
# dtype: int64

# %%
data.drop('Junction_Detail',axis=1,inplace=True)
data.drop('Junction_Control',axis=1,inplace=True)
filtered_data = data.dropna()

# %%
filtered_data.shape
# Out:
# (28098, 31)

# %%
filtered_data.drop('Accident_Index',axis=1,inplace=True)
filtered_data.drop('LSOA_of_Accident_Location',axis=1,inplace=True)
filtered_data.drop('Local_Authority_(Highway)',axis=1,inplace=True)
filtered_data.drop('Date',axis=1,inplace=True)
filtered_data.drop('Time',axis=1,inplace=True)

# %%
df_onehot = pd.get_dummies(filtered_data)
df_onehot.dtypes
# Out:
# Location_Easting_OSGR                                            int64
# Location_Northing_OSGR                                           int64
# Longitude                                                      float64
# Latitude                                                       float64
# Police_Force                                                     int64
#                                                                 ...
# Carriageway_Hazards_None                                         uint8
# Carriageway_Hazards_Other object in carriageway                  uint8
# Carriageway_Hazards_Pedestrian in carriageway (not injured)      uint8
# Did_Police_Officer_Attend_Scene_of_Accident_No                   uint8
# Did_Police_Officer_Attend_Scene_of_Accident_Yes                  uint8
# Length: 67, dtype: object

# %%
X = df_onehot.loc[:, df_onehot.columns != 'Accident_Severity']
y = df_onehot[['Accident_Severity']]

# %%
from sklearn.preprocessing import StandardScaler

# create a StandardScaler model
scaler = StandardScaler()

# fit and transform the data
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns= X.columns)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (19668, 66)
# (19668, 1)
# (8430, 66)
# (8430, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [12:25<00:00, 25.70s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.49               0.47    None      0.58
# ExtraTreeClassifier                0.76               0.39    None      0.76
# LabelSpreading                     0.76               0.39    None      0.76
# LabelPropagation                   0.75               0.39    None      0.76
# DecisionTreeClassifier             0.76               0.39    None      0.76
# BaggingClassifier                  0.82               0.38    None      0.79
# ExtraTreesClassifier               0.85               0.37    None      0.80
# RandomForestClassifier             0.85               0.37    None      0.80
# BernoulliNB                        0.83               0.37    None      0.77
# LGBMClassifier                     0.84               0.35    None      0.78
# KNeighborsClassifier               0.82               0.35    None      0.78
# GaussianNB                         0.04               0.34    None      0.05
# QuadraticDiscriminantAnalysis      0.07               0.34    None      0.11
# LinearDiscriminantAnalysis         0.84               0.34    None      0.77
# Perceptron                         0.81               0.34    None      0.77
# PassiveAggressiveClassifier        0.83               0.34    None      0.77
# AdaBoostClassifier                 0.84               0.33    None      0.77
# LinearSVC                          0.84               0.33    None      0.77
# DummyClassifier                    0.84               0.33    None      0.77
# CalibratedClassifierCV             0.84               0.33    None      0.77
# RidgeClassifier                    0.84               0.33    None      0.77
# RidgeClassifierCV                  0.84               0.33    None      0.77
# SVC                                0.84               0.33    None      0.77
# LogisticRegression                 0.84               0.33    None      0.77
# SGDClassifier                      0.84               0.33    None      0.77
#
#                                Time Taken
# Model
# NearestCentroid                      0.36
# ExtraTreeClassifier                  0.21
# LabelSpreading                     155.96
# LabelPropagation                   116.69
# DecisionTreeClassifier               0.92
# BaggingClassifier                    5.22
# ExtraTreesClassifier                10.27
# RandomForestClassifier               8.08
# BernoulliNB                          0.21
# LGBMClassifier                       3.85
# KNeighborsClassifier                 2.18
# GaussianNB                           0.21
# QuadraticDiscriminantAnalysis        0.74
# LinearDiscriminantAnalysis           1.81
# Perceptron                           0.42
# PassiveAggressiveClassifier          0.55
# AdaBoostClassifier                   3.70
# LinearSVC                           36.46
# DummyClassifier                      0.12
# CalibratedClassifierCV             173.13
# RidgeClassifier                      0.67
# RidgeClassifierCV                    0.88
# SVC                                217.87
# LogisticRegression                   2.06
# SGDClassifier                        1.43

# %% [markdown]
# #### Dimensionality Reduction Algorithm

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)

principalComponents = pca.fit_transform(X_scaled)

PCA_Df = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5'])

# %%
trainX, testX, trainy, testy = train_test_split(PCA_Df, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (19668, 5)
# (19668, 1)
# (8430, 5)
# (8430, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [02:50<00:00,  5.88s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.45               0.47    None      0.55
# DecisionTreeClassifier             0.76               0.41    None      0.76
# ExtraTreeClassifier                0.76               0.41    None      0.76
# ExtraTreesClassifier               0.84               0.39    None      0.80
# RandomForestClassifier             0.85               0.39    None      0.80
# BaggingClassifier                  0.82               0.39    None      0.79
# LabelPropagation                   0.82               0.36    None      0.78
# LabelSpreading                     0.83               0.36    None      0.78
# LGBMClassifier                     0.85               0.34    None      0.78
# KNeighborsClassifier               0.82               0.34    None      0.78
# SVC                                0.85               0.33    None      0.78
# SGDClassifier                      0.85               0.33    None      0.78
# RidgeClassifierCV                  0.85               0.33    None      0.78
# RidgeClassifier                    0.85               0.33    None      0.78
# AdaBoostClassifier                 0.85               0.33    None      0.78
# LogisticRegression                 0.85               0.33    None      0.78
# LinearSVC                          0.85               0.33    None      0.78
# GaussianNB                         0.85               0.33    None      0.78
# DummyClassifier                    0.85               0.33    None      0.78
# CalibratedClassifierCV             0.85               0.33    None      0.78
# BernoulliNB                        0.85               0.33    None      0.78
# LinearDiscriminantAnalysis         0.85               0.33    None      0.78
# QuadraticDiscriminantAnalysis      0.85               0.33    None      0.78
# Perceptron                         0.84               0.33    None      0.77
# PassiveAggressiveClassifier        0.83               0.33    None      0.77
#
#                                Time Taken
# Model
# NearestCentroid                      0.06
# DecisionTreeClassifier               0.32
# ExtraTreeClassifier                  0.07
# ExtraTreesClassifier                 3.48
# RandomForestClassifier               8.66
# BaggingClassifier                    2.20
# LabelPropagation                    23.69
# LabelSpreading                      37.78
# LGBMClassifier                       0.98
# KNeighborsClassifier                 0.71
# SVC                                 46.95
# SGDClassifier                        0.19
# RidgeClassifierCV                    0.06
# RidgeClassifier                      0.07
# AdaBoostClassifier                   1.87
# LogisticRegression                   0.19
# LinearSVC                           10.28
# GaussianNB                           0.05
# DummyClassifier                      0.04
# CalibratedClassifierCV              32.27
# BernoulliNB                          0.06
# LinearDiscriminantAnalysis           0.07
# QuadraticDiscriminantAnalysis        0.08
# Perceptron                           0.10
# PassiveAggressiveClassifier          0.12

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# create an LDA model
lda = LDA(n_components=1)

# fit and transform the data
X_reduced = lda.fit_transform(X_scaled, y)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (19668, 66)
# (19668, 1)
# (8430, 66)
# (8430, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [07:35<00:00, 15.71s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.52               0.48    None      0.61
# ExtraTreeClassifier                0.76               0.42    None      0.77
# LabelSpreading                     0.76               0.42    None      0.76
# DecisionTreeClassifier             0.75               0.42    None      0.76
# LabelPropagation                   0.76               0.42    None      0.76
# BaggingClassifier                  0.83               0.41    None      0.80
# ExtraTreesClassifier               0.85               0.40    None      0.80
# RandomForestClassifier             0.86               0.39    None      0.80
# BernoulliNB                        0.83               0.38    None      0.77
# PassiveAggressiveClassifier        0.78               0.37    None      0.76
# Perceptron                         0.77               0.36    None      0.76
# LGBMClassifier                     0.85               0.36    None      0.78
# QuadraticDiscriminantAnalysis      0.09               0.35    None      0.14
# KNeighborsClassifier               0.83               0.35    None      0.79
# GaussianNB                         0.03               0.34    None      0.04
# SVC                                0.85               0.33    None      0.78
# LinearSVC                          0.85               0.33    None      0.78
# LogisticRegression                 0.85               0.33    None      0.78
# SGDClassifier                      0.85               0.33    None      0.78
# RidgeClassifierCV                  0.85               0.33    None      0.78
# AdaBoostClassifier                 0.85               0.33    None      0.78
# RidgeClassifier                    0.85               0.33    None      0.78
# DummyClassifier                    0.85               0.33    None      0.78
# CalibratedClassifierCV             0.85               0.33    None      0.78
# LinearDiscriminantAnalysis         0.85               0.33    None      0.78
#
#                                Time Taken
# Model
# NearestCentroid                      0.14
# ExtraTreeClassifier                  0.22
# LabelSpreading                      69.85
# DecisionTreeClassifier               0.73
# LabelPropagation                    53.88
# BaggingClassifier                    4.15
# ExtraTreesClassifier                 7.87
# RandomForestClassifier               7.83
# BernoulliNB                          0.19
# PassiveAggressiveClassifier          0.31
# Perceptron                           0.25
# LGBMClassifier                       1.76
# QuadraticDiscriminantAnalysis        0.38
# KNeighborsClassifier                 1.77
# GaussianNB                           0.18
# SVC                                129.72
# LinearSVC                           33.86
# LogisticRegression                   1.16
# SGDClassifier                        1.76
# RidgeClassifierCV                    0.49
# AdaBoostClassifier                   3.20
# RidgeClassifier                      0.19
# DummyClassifier                      0.13
# CalibratedClassifierCV             134.61
# LinearDiscriminantAnalysis           0.50

# %%
from sklearn.manifold import TSNE
# Initialize the t-SNE model
model = TSNE(n_components=2)
X_reduced = model.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (19668, 66)
# (19668, 1)
# (8430, 66)
# (8430, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [06:35<00:00, 13.65s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.52               0.48    None      0.61
# ExtraTreeClassifier                0.76               0.42    None      0.77
# LabelSpreading                     0.76               0.42    None      0.76
# DecisionTreeClassifier             0.75               0.42    None      0.76
# LabelPropagation                   0.76               0.42    None      0.76
# BaggingClassifier                  0.83               0.41    None      0.80
# ExtraTreesClassifier               0.85               0.40    None      0.80
# RandomForestClassifier             0.86               0.39    None      0.80
# BernoulliNB                        0.83               0.38    None      0.77
# PassiveAggressiveClassifier        0.78               0.37    None      0.76
# Perceptron                         0.77               0.36    None      0.76
# LGBMClassifier                     0.85               0.36    None      0.78
# QuadraticDiscriminantAnalysis      0.09               0.35    None      0.14
# KNeighborsClassifier               0.83               0.35    None      0.79
# GaussianNB                         0.03               0.34    None      0.04
# SVC                                0.85               0.33    None      0.78
# LinearSVC                          0.85               0.33    None      0.78
# LogisticRegression                 0.85               0.33    None      0.78
# SGDClassifier                      0.85               0.33    None      0.78
# RidgeClassifierCV                  0.85               0.33    None      0.78
# AdaBoostClassifier                 0.85               0.33    None      0.78
# RidgeClassifier                    0.85               0.33    None      0.78
# DummyClassifier                    0.85               0.33    None      0.78
# CalibratedClassifierCV             0.85               0.33    None      0.78
# LinearDiscriminantAnalysis         0.85               0.33    None      0.78
#
#                                Time Taken
# Model
# NearestCentroid                      0.13
# ExtraTreeClassifier                  0.56
# LabelSpreading                      56.60
# DecisionTreeClassifier               1.70
# LabelPropagation                    50.97
# BaggingClassifier                    3.36
# ExtraTreesClassifier                12.00
# RandomForestClassifier               5.03
# BernoulliNB                          0.16
# PassiveAggressiveClassifier          0.23
# Perceptron                           0.19
# LGBMClassifier                       1.24
# QuadraticDiscriminantAnalysis        0.30
# KNeighborsClassifier                 1.42
# GaussianNB                           0.13
# SVC                                115.88
# LinearSVC                           30.70
# LogisticRegression                   0.89
# SGDClassifier                        1.25
# RidgeClassifierCV                    0.36
# AdaBoostClassifier                   2.41
# RidgeClassifier                      0.15
# DummyClassifier                      0.29
# CalibratedClassifierCV             109.02
# LinearDiscriminantAnalysis           0.41

# %%
from sklearn.decomposition import TruncatedSVD

# create a SVD model
svd = TruncatedSVD(n_components=5)

# fit and transform the data
X_reduced = svd.fit_transform(X_scaled)

# %%
trainX, testX, trainy, testy = train_test_split(X_scaled, y, test_size=0.3, random_state=2)
print(trainX.shape)
print(trainy.shape)
print(testX.shape)
print(testy.shape)
# Out:
# (19668, 66)
# (19668, 1)
# (8430, 66)
# (8430, 1)

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(trainX, testX, trainy, testy)
models
# Out:
# 100%|██████████| 29/29 [06:49<00:00, 14.13s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.52               0.48    None      0.61
# ExtraTreeClassifier                0.76               0.42    None      0.77
# LabelSpreading                     0.76               0.42    None      0.76
# DecisionTreeClassifier             0.75               0.42    None      0.76
# LabelPropagation                   0.76               0.42    None      0.76
# BaggingClassifier                  0.83               0.41    None      0.80
# ExtraTreesClassifier               0.85               0.40    None      0.80
# RandomForestClassifier             0.86               0.39    None      0.80
# BernoulliNB                        0.83               0.38    None      0.77
# PassiveAggressiveClassifier        0.78               0.37    None      0.76
# Perceptron                         0.77               0.36    None      0.76
# LGBMClassifier                     0.85               0.36    None      0.78
# QuadraticDiscriminantAnalysis      0.09               0.35    None      0.14
# KNeighborsClassifier               0.83               0.35    None      0.79
# GaussianNB                         0.03               0.34    None      0.04
# SVC                                0.85               0.33    None      0.78
# LinearSVC                          0.85               0.33    None      0.78
# LogisticRegression                 0.85               0.33    None      0.78
# SGDClassifier                      0.85               0.33    None      0.78
# RidgeClassifierCV                  0.85               0.33    None      0.78
# AdaBoostClassifier                 0.85               0.33    None      0.78
# RidgeClassifier                    0.85               0.33    None      0.78
# DummyClassifier                    0.85               0.33    None      0.78
# CalibratedClassifierCV             0.85               0.33    None      0.78
# LinearDiscriminantAnalysis         0.85               0.33    None      0.78
#
#                                Time Taken
# Model
# NearestCentroid                      0.12
# ExtraTreeClassifier                  0.13
# LabelSpreading                      60.05
# DecisionTreeClassifier               0.46
# LabelPropagation                    49.52
# BaggingClassifier                    3.32
# ExtraTreesClassifier                 5.65
# RandomForestClassifier               7.15
# BernoulliNB                          0.18
# PassiveAggressiveClassifier          0.27
# Perceptron                           0.22
# LGBMClassifier                       2.08
# QuadraticDiscriminantAnalysis        0.31
# KNeighborsClassifier                 1.31
# GaussianNB                           0.15
# SVC                                124.60
# LinearSVC                           30.99
# LogisticRegression                   0.94
# SGDClassifier                        1.45
# RidgeClassifierCV                    0.40
# AdaBoostClassifier                   2.85
# RidgeClassifier                      0.16
# DummyClassifier                      0.09
# CalibratedClassifierCV             116.63
# LinearDiscriminantAnalysis           0.44

# %% [markdown]
# ## Conclusion

# %% [markdown]
# For Classification
#
# we have noticed that after implementing dimensionality reduction techniques, performance of the models increased but accuracy of some models decrease after doing dimensionality reduction using isomap embedding and T-SNE
#
# For some dataset, where dimensions are not too high, performance of models decrease after reducing dimensions. This is because data is losing important patterns in the dataset because dimension is already very low.
#
# Computational time of the model reduce after reducing the dimensions, as the number of features to learn reduce for the model.
#
# PCA and LDA are performing better as compare to the other dimensionality reduction technique. The fact that LDA is a supervised technique, which is also one of its disadvantages, is the main reason it outperforms the other techniques. However, since our attention is on classification, we would need a labelled dataset, and LDA makes use of the labels in conjunction with the dataset to improve class separability.
